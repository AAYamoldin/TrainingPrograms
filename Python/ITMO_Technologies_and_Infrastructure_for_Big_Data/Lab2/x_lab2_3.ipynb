# %%
import os
import datetime
import socket
from pyspark import SparkConf, SparkContext, SQLContext
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, length, when, col, desc
from pyspark.sql.types import BooleanType, IntegerType, LongType, StringType, ArrayType, FloatType, StructType, StructField
import pyspark.sql.functions as F
from pyspark.sql.functions import pandas_udf
from pyspark.sql.functions import PandasUDFType
from jinja2 import Environment, FileSystemLoader

# %%
# setting constants
APP_NAME = "VVORONIN-SPARK-APP"
NORMALIZED_APP_NAME = APP_NAME.replace('/', '_').replace(':', '_')

APPS_TMP_DIR = os.path.join(os.getcwd(), "tmp")
APPS_CONF_DIR = os.path.join(os.getcwd(), "conf")
APPS_LOGS_DIR = os.path.join(os.getcwd(), "logs")
LOG4J_PROP_FILE = os.path.join(APPS_CONF_DIR, "pyspark-log4j-{}.properties".format(NORMALIZED_APP_NAME))
LOG_FILE = os.path.join(APPS_LOGS_DIR, 'pyspark-{}.log'.format(NORMALIZED_APP_NAME))
EXTRA_JAVA_OPTIONS = "-Dlog4j.configuration=file://{} -Dspark.hadoop.dfs.replication=1 -Dhttps.protocols=TLSv1.0,TLSv1.1,TLSv1.2,TLSv1.3"\
    .format(LOG4J_PROP_FILE)

LOCAL_IP = socket.gethostbyname(socket.gethostname())

# %%
# preparing configuration files from templates
for directory in [APPS_CONF_DIR, APPS_LOGS_DIR, APPS_TMP_DIR]:
    if not os.path.exists(directory):
        os.makedirs(directory)

env = Environment(loader=FileSystemLoader('/opt'))
template = env.get_template("pyspark_log4j.properties.template")
template\
    .stream(logfile=LOG_FILE)\
    .dump(LOG4J_PROP_FILE)

# %% [markdown]
# # Run spark

# %%
# spark = SparkSession\
#     .builder\
#     .appName(APP_NAME)\
#     .master("k8s://https://10.32.7.103:6443")\
#     .config("spark.driver.host", LOCAL_IP)\
#     .config("spark.driver.bindAddress", "0.0.0.0")\
#     .config("spark.executor.instances", "3")\
#     .config("spark.executor.cores", '2')\
#     .config("spark.memory.fraction", "0.8")\
#     .config("spark.memory.storageFraction", "0.6")\
#     .config("spark.executor.memory", "4g")\
#     .config("spark.driver.extraJavaOptions", EXTRA_JAVA_OPTIONS)\
#     .config("spark.kubernetes.namespace", "{{user}}")\
#     .config("spark.kubernetes.driver.label.appname", APP_NAME)\
#     .config("spark.kubernetes.executor.label.appname", APP_NAME)\
#     .config("spark.kubernetes.container.image.pullPolicy", "Always")\
#     .config("spark.kubernetes.container.image", "node03.st:5000/spark-executor:{{user}}")\
#     .config("spark.local.dir", "/tmp/spark")\
#     .getOrCreate()

SPARK_ADDRESS = "k8s://https://10.32.7.103:6443"

spark = SparkSession\
    .builder\
    .appName("VVORONIN-SPARK-APP")\
    .master(SPARK_ADDRESS)\
    .config("spark.ui.port", "4040")\
    .config("spark.memory.fraction", "0.8")\
    .config("spark.memory.storageFraction", "0.6")\
    .config("spark.driver.memory", "4g")\
    .config("spark.driver.extraJavaOptions", EXTRA_JAVA_OPTIONS)\
    .config("spark.executor.memory", "6g")\
    .getOrCreate()

# %%
# printing important urls and pathes
print("Web UI: {}".format(spark.sparkContext.uiWebUrl))
print("\nlog4j file: {}".format(LOG4J_PROP_FILE))
print("\ndriver log file: {}".format(LOG_FILE))
# Out:
# Web UI: http://jupyter-spark-75c86b84fb-grxm2:4040
#
# log4j file: /home/jovyan/work/conf/pyspark-log4j-VVORONIN-SPARK-APP.properties
#
# driver log file: /home/jovyan/work/logs/pyspark-VVORONIN-SPARK-APP.log

# %% [markdown]
# # Read data

# %%
#there were created five tasks in apache spark webUI
posts_df = spark.read.json("hdfs:///shared/bigdata20/posts_api.json")
posts_likes_df = spark.read.parquet("hdfs:///shared/bigdata20/posts_likes.parquet")
followers_df = spark.read.parquet("hdfs:///shared/bigdata20/followers.parquet")
followers_posts_df = spark.read.json("hdfs:///shared/bigdata20/followers_posts_api_final.json")
followers_posts_likes_df = spark.read.parquet("hdfs:///shared/bigdata20/followers_posts_likes.parquet")

# %%
followers_df.head(5)
# Out:
# [Row(profile=-94, follower=34),
#  Row(profile=-94, follower=87),
#  Row(profile=-94, follower=102),
#  Row(profile=-94, follower=175),
#  Row(profile=-94, follower=533)]

# %%
followers_posts_likes_df.printSchema()
# Out:
# root
#  |-- itemType: string (nullable = true)
#  |-- ownerId: integer (nullable = true)
#  |-- itemId: integer (nullable = true)
#  |-- likerId: integer (nullable = true)

# %%
posts_likes_df.printSchema()
#itemId = PostID - уникальный номер поста
#ownerId - id группы, где пост размещен
#likerId - ID того, кто создал пост
# Out:
# root
#  |-- itemType: string (nullable = true)
#  |-- ownerId: integer (nullable = true)
#  |-- itemId: integer (nullable = true)
#  |-- likerId: integer (nullable = true)

# %% [markdown]
# # Task1
# #### Find the top 20 posts in the group:
# * by likes;
# * by comments;
# * by reposts

# %% [markdown]
# ### топ-20 постов по числу лайков

# %%
likes = posts_df.select('id', col('likes.count').name('likes'))\
    .orderBy("likes", ascending = False)\
    .limit(20)

# %%
likes.collect()
# Out:
# [Row(id=32022, likes=1637),
#  Row(id=35068, likes=1629),
#  Row(id=17492, likes=1516),
#  Row(id=18526, likes=1026),
#  Row(id=19552, likes=955),
#  Row(id=41468, likes=952),
#  Row(id=19419, likes=868),
#  Row(id=29046, likes=824),
#  Row(id=32546, likes=786),
#  Row(id=24085, likes=765),
#  Row(id=40180, likes=759),
#  Row(id=33658, likes=708),
#  Row(id=13532, likes=633),
#  Row(id=40842, likes=631),
#  Row(id=35117, likes=588),
#  Row(id=17014, likes=581),
#  Row(id=19583, likes=553),
#  Row(id=19809, likes=552),
#  Row(id=27455, likes=550),
#  Row(id=11999, likes=549)]

# %% [markdown]
# альтернативный вариант через группировку данных

# %%
pl_df = posts_likes_df.groupby("itemId")\
    .agg(F.count('likerId').name("likes_count"))\
    .withColumnRenamed("itemId", "post_id")\
    .orderBy("likes_count", ascending = False)\
    .limit(20)

# %%
#поскольку реализована схема "ленивых" вычислений для отображения результатов требуется отдельной командой вычислить функцию
pl_df.collect()
# Out:
# [Row(post_id=32022, likes_count=1654),
#  Row(post_id=35068, likes_count=1630),
#  Row(post_id=17492, likes_count=1538),
#  Row(post_id=18526, likes_count=1028),
#  Row(post_id=19552, likes_count=955),
#  Row(post_id=41468, likes_count=952),
#  Row(post_id=19419, likes_count=868),
#  Row(post_id=29046, likes_count=824),
#  Row(post_id=32546, likes_count=786),
#  Row(post_id=24085, likes_count=765),
#  Row(post_id=40180, likes_count=759),
#  Row(post_id=33658, likes_count=708),
#  Row(post_id=13532, likes_count=633),
#  Row(post_id=40842, likes_count=631),
#  Row(post_id=35117, likes_count=588),
#  Row(post_id=17014, likes_count=581),
#  Row(post_id=19583, likes_count=553),
#  Row(post_id=19809, likes_count=552),
#  Row(post_id=27455, likes_count=550),
#  Row(post_id=11999, likes_count=549)]

# %% [markdown]
# ### топ-20 постов по числу комментов

# %%
pс_df = posts_df.groupby("id")\
    .agg(F.count('comments').name("comments_count"))\
    .withColumnRenamed("id", "post_id")\
    .orderBy("comments_count", ascending = False)\
    .limit(20)

# %%
pс_df.collect()
# Out:
# [Row(post_id=13509, comments_count=1),
#  Row(post_id=1642, comments_count=1),
#  Row(post_id=17201, comments_count=1),
#  Row(post_id=18957, comments_count=1),
#  Row(post_id=34453, comments_count=1),
#  Row(post_id=15894, comments_count=1),
#  Row(post_id=34304, comments_count=1),
#  Row(post_id=1551, comments_count=1),
#  Row(post_id=17558, comments_count=1),
#  Row(post_id=5148, comments_count=1),
#  Row(post_id=17647, comments_count=1),
#  Row(post_id=3327, comments_count=1),
#  Row(post_id=3937, comments_count=1),
#  Row(post_id=27693, comments_count=1),
#  Row(post_id=1409, comments_count=1),
#  Row(post_id=3155, comments_count=1),
#  Row(post_id=16100, comments_count=1),
#  Row(post_id=28283, comments_count=1),
#  Row(post_id=2989, comments_count=1),
#  Row(post_id=2994, comments_count=1)]

# %% [markdown]
# ### топ-20 постов по числу репостов

# %%
pr_df = posts_df.select('id', col('reposts.count').name('reposts'))\
    .orderBy('reposts', ascending = False)\
    .limit(20)

# %%
pr_df.collect()
# Out:
# [Row(id=17492, reposts=334),
#  Row(id=19552, reposts=246),
#  Row(id=32022, reposts=210),
#  Row(id=11842, reposts=129),
#  Row(id=19419, reposts=126),
#  Row(id=13532, reposts=110),
#  Row(id=17014, reposts=105),
#  Row(id=35068, reposts=101),
#  Row(id=41266, reposts=92),
#  Row(id=12593, reposts=90),
#  Row(id=29046, reposts=87),
#  Row(id=11999, reposts=85),
#  Row(id=41468, reposts=85),
#  Row(id=19809, reposts=84),
#  Row(id=17167, reposts=81),
#  Row(id=10833, reposts=78),
#  Row(id=18543, reposts=77),
#  Row(id=16596, reposts=76),
#  Row(id=18156, reposts=74),
#  Row(id=37262, reposts=71)]

# %% [markdown]
# # Task 2
# #### Find the top 20 users by
# * likes
# * reposts they have made (to trace reposts use "copy_history" field)

# %% [markdown]
# ### топ-20 пользователей по числу лайков

# %%
posts_likes_df.printSchema()
# Out:
# root
#  |-- itemType: string (nullable = true)
#  |-- ownerId: integer (nullable = true)
#  |-- itemId: integer (nullable = true)
#  |-- likerId: integer (nullable = true)

# %%
posts_likes_df.groupby('likerId')\
    .agg(F.count('itemId').name('likes'))\
    .withColumnRenamed("likerId", "user_id")\
    .orderBy('likes', ascending = False)\
    .limit(20)\
    .collect()
# Out:
# [Row(user_id=2070090, likes=4801),
#  Row(user_id=2397858, likes=2055),
#  Row(user_id=1475301, likes=1829),
#  Row(user_id=18239, likes=1569),
#  Row(user_id=546612, likes=1245),
#  Row(user_id=6371, likes=907),
#  Row(user_id=1841959, likes=746),
#  Row(user_id=78440957, likes=709),
#  Row(user_id=120248, likes=699),
#  Row(user_id=40981497, likes=611),
#  Row(user_id=22158, likes=553),
#  Row(user_id=207628162, likes=548),
#  Row(user_id=329377723, likes=504),
#  Row(user_id=76071304, likes=474),
#  Row(user_id=14805173, likes=440),
#  Row(user_id=317799, likes=385),
#  Row(user_id=56355640, likes=375),
#  Row(user_id=52042971, likes=338),
#  Row(user_id=7437271, likes=336),
#  Row(user_id=136506644, likes=335)]

# %% [markdown]
# ### топ-20 пользователей по числу репостов

# %%
followers_posts_df\
    .where("copy_history is not null")\
        .select(
            col("owner_id"),
            col("copy_history.id").alias("post_id"),
            col("copy_history.owner_id").alias("src_owner_id"))\
        .groupBy("owner_id")\
        .agg(F.count("post_id").alias("count"))\
        .orderBy(F.desc("count"))\
    .limit(20)\
    .collect()
# Out:
# [Row(owner_id=2547211, count=37742),
#  Row(owner_id=357231922, count=23349),
#  Row(owner_id=168543860, count=18429),
#  Row(owner_id=25646344, count=11122),
#  Row(owner_id=176861294, count=9022),
#  Row(owner_id=524656784, count=7242),
#  Row(owner_id=29840, count=7164),
#  Row(owner_id=143207077, count=7161),
#  Row(owner_id=141687240, count=6804),
#  Row(owner_id=459339006, count=6741),
#  Row(owner_id=514384760, count=6570),
#  Row(owner_id=483715951, count=6052),
#  Row(owner_id=445159771, count=5808),
#  Row(owner_id=451211328, count=5646),
#  Row(owner_id=426396104, count=5533),
#  Row(owner_id=8325325, count=5532),
#  Row(owner_id=452280411, count=5458),
#  Row(owner_id=464220898, count=5318),
#  Row(owner_id=440454268, count=5304),
#  Row(owner_id=461319529, count=5240)]

# %% [markdown]
# # Task 3
# get reposts of the original posts of the itmo group (posts.json) from user posts (the result should be similar to (group_post_id, Array (user_post_ids)))

# %%
followers_posts_df.printSchema()
# Out:
# root
#  |-- attachments: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- album: struct (nullable = true)
#  |    |    |    |-- created: long (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- size: long (nullable = true)
#  |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |-- long: double (nullable = true)
#  |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- updated: long (nullable = true)
#  |    |    |-- audio: struct (nullable = true)
#  |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |-- content_restricted: long (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |-- genre_id: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- is_hq: boolean (nullable = true)
#  |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- doc: struct (nullable = true)
#  |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- ext: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- preview: struct (nullable = true)
#  |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- video: struct (nullable = true)
#  |    |    |    |    |    |-- file_size: long (nullable = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |-- size: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- type: long (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- link: struct (nullable = true)
#  |    |    |    |-- button: struct (nullable = true)
#  |    |    |    |    |-- action: struct (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- button_action: string (nullable = true)
#  |    |    |    |-- button_text: string (nullable = true)
#  |    |    |    |-- caption: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |-- long: double (nullable = true)
#  |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- src_big: string (nullable = true)
#  |    |    |    |    |-- src_small: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |-- target: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- market: struct (nullable = true)
#  |    |    |    |-- availability: long (nullable = true)
#  |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- section: struct (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- price: struct (nullable = true)
#  |    |    |    |    |-- amount: string (nullable = true)
#  |    |    |    |    |-- currency: struct (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- thumb_photo: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |-- page: struct (nullable = true)
#  |    |    |    |-- created: long (nullable = true)
#  |    |    |    |-- creator_id: long (nullable = true)
#  |    |    |    |-- current_user_can_edit: long (nullable = true)
#  |    |    |    |-- current_user_can_edit_access: long (nullable = true)
#  |    |    |    |-- edited: long (nullable = true)
#  |    |    |    |-- editor_id: long (nullable = true)
#  |    |    |    |-- group_id: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- view_url: string (nullable = true)
#  |    |    |    |-- views: long (nullable = true)
#  |    |    |    |-- who_can_edit: long (nullable = true)
#  |    |    |    |-- who_can_view: long (nullable = true)
#  |    |    |-- photo: struct (nullable = true)
#  |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |-- long: double (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- user_id: long (nullable = true)
#  |    |    |-- photos_list: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- podcast: struct (nullable = true)
#  |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- is_hq: boolean (nullable = true)
#  |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- podcast_info: struct (nullable = true)
#  |    |    |    |    |-- cover: struct (nullable = true)
#  |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- plays: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- poll: struct (nullable = true)
#  |    |    |    |-- anonymous: long (nullable = true)
#  |    |    |    |-- answer_id: long (nullable = true)
#  |    |    |    |-- answers: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- rate: double (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- votes: long (nullable = true)
#  |    |    |    |-- created: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- question: string (nullable = true)
#  |    |    |    |-- votes: long (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- video: struct (nullable = true)
#  |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |-- can_add: long (nullable = true)
#  |    |    |    |-- comments: long (nullable = true)
#  |    |    |    |-- content_restricted: long (nullable = true)
#  |    |    |    |-- date: long (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |-- first_frame_1024: string (nullable = true)
#  |    |    |    |-- first_frame_1280: string (nullable = true)
#  |    |    |    |-- first_frame_130: string (nullable = true)
#  |    |    |    |-- first_frame_160: string (nullable = true)
#  |    |    |    |-- first_frame_320: string (nullable = true)
#  |    |    |    |-- first_frame_4096: string (nullable = true)
#  |    |    |    |-- first_frame_720: string (nullable = true)
#  |    |    |    |-- first_frame_800: string (nullable = true)
#  |    |    |    |-- height: long (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- is_private: long (nullable = true)
#  |    |    |    |-- live: long (nullable = true)
#  |    |    |    |-- local_views: long (nullable = true)
#  |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |-- photo_1280: string (nullable = true)
#  |    |    |    |-- photo_130: string (nullable = true)
#  |    |    |    |-- photo_320: string (nullable = true)
#  |    |    |    |-- photo_640: string (nullable = true)
#  |    |    |    |-- photo_800: string (nullable = true)
#  |    |    |    |-- platform: string (nullable = true)
#  |    |    |    |-- processing: long (nullable = true)
#  |    |    |    |-- repeat: long (nullable = true)
#  |    |    |    |-- spectators: long (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- track_code: string (nullable = true)
#  |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |-- views: long (nullable = true)
#  |    |    |    |-- width: long (nullable = true)
#  |-- comments: struct (nullable = true)
#  |    |-- can_post: long (nullable = true)
#  |    |-- count: long (nullable = true)
#  |    |-- groups_can_post: boolean (nullable = true)
#  |-- copy_history: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- attachments: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- album: struct (nullable = true)
#  |    |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |    |    |-- long: double (nullable = true)
#  |    |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- updated: long (nullable = true)
#  |    |    |    |    |-- audio: struct (nullable = true)
#  |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |    |    |-- content_restricted: long (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |    |    |-- genre_id: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- is_hq: boolean (nullable = true)
#  |    |    |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- doc: struct (nullable = true)
#  |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- ext: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- preview: struct (nullable = true)
#  |    |    |    |    |    |    |-- graffiti: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- video: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- file_size: long (nullable = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- src: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- type: long (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- link: struct (nullable = true)
#  |    |    |    |    |    |-- button: struct (nullable = true)
#  |    |    |    |    |    |    |-- action: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- group_id: long (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- button_action: string (nullable = true)
#  |    |    |    |    |    |-- button_text: string (nullable = true)
#  |    |    |    |    |    |-- caption: string (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |    |    |-- long: double (nullable = true)
#  |    |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |    |-- product: struct (nullable = true)
#  |    |    |    |    |    |    |-- price: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- amount: string (nullable = true)
#  |    |    |    |    |    |    |    |-- currency: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- target: string (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- video: struct (nullable = true)
#  |    |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |    |-- can_add: long (nullable = true)
#  |    |    |    |    |    |    |-- comments: long (nullable = true)
#  |    |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_1024: string (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_1280: string (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_130: string (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_160: string (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_320: string (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_4096: string (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_720: string (nullable = true)
#  |    |    |    |    |    |    |-- first_frame_800: string (nullable = true)
#  |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |    |-- photo_1280: string (nullable = true)
#  |    |    |    |    |    |    |-- photo_130: string (nullable = true)
#  |    |    |    |    |    |    |-- photo_320: string (nullable = true)
#  |    |    |    |    |    |    |-- photo_800: string (nullable = true)
#  |    |    |    |    |    |    |-- processing: long (nullable = true)
#  |    |    |    |    |    |    |-- repeat: long (nullable = true)
#  |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |-- track_code: string (nullable = true)
#  |    |    |    |    |    |    |-- views: long (nullable = true)
#  |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |-- market: struct (nullable = true)
#  |    |    |    |    |    |-- availability: long (nullable = true)
#  |    |    |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |-- section: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- price: struct (nullable = true)
#  |    |    |    |    |    |    |-- amount: string (nullable = true)
#  |    |    |    |    |    |    |-- currency: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- thumb_photo: string (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- market_album: struct (nullable = true)
#  |    |    |    |    |    |-- count: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- updated_time: long (nullable = true)
#  |    |    |    |    |-- note: struct (nullable = true)
#  |    |    |    |    |    |-- comments: long (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- read_comments: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- view_url: string (nullable = true)
#  |    |    |    |    |-- page: struct (nullable = true)
#  |    |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |    |-- creator_id: long (nullable = true)
#  |    |    |    |    |    |-- current_user_can_edit: long (nullable = true)
#  |    |    |    |    |    |-- current_user_can_edit_access: long (nullable = true)
#  |    |    |    |    |    |-- edited: long (nullable = true)
#  |    |    |    |    |    |-- editor_id: long (nullable = true)
#  |    |    |    |    |    |-- group_id: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- parent: string (nullable = true)
#  |    |    |    |    |    |-- parent2: string (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- view_url: string (nullable = true)
#  |    |    |    |    |    |-- views: long (nullable = true)
#  |    |    |    |    |    |-- who_can_edit: long (nullable = true)
#  |    |    |    |    |    |-- who_can_view: long (nullable = true)
#  |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |    |    |-- long: double (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- post_id: long (nullable = true)
#  |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |-- photos_list: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- podcast: struct (nullable = true)
#  |    |    |    |    |    |-- artist: string (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- is_explicit: boolean (nullable = true)
#  |    |    |    |    |    |-- is_hq: boolean (nullable = true)
#  |    |    |    |    |    |-- lyrics_id: long (nullable = true)
#  |    |    |    |    |    |-- no_search: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- podcast_info: struct (nullable = true)
#  |    |    |    |    |    |    |-- cover: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- sizes: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |    |-- plays: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- poll: struct (nullable = true)
#  |    |    |    |    |    |-- anonymous: long (nullable = true)
#  |    |    |    |    |    |-- answer_id: long (nullable = true)
#  |    |    |    |    |    |-- answers: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |    |    |-- rate: double (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |    |-- votes: long (nullable = true)
#  |    |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- question: string (nullable = true)
#  |    |    |    |    |    |-- votes: long (nullable = true)
#  |    |    |    |    |-- pretty_cards: struct (nullable = true)
#  |    |    |    |    |    |-- cards: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- button: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- action: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- group_id: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- target: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |    |-- card_id: string (nullable = true)
#  |    |    |    |    |    |    |    |-- images: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |    |    |-- link_url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- link_url_target: string (nullable = true)
#  |    |    |    |    |    |    |    |-- photo: string (nullable = true)
#  |    |    |    |    |    |    |    |-- price: string (nullable = true)
#  |    |    |    |    |    |    |    |-- price_old: string (nullable = true)
#  |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- sticker: struct (nullable = true)
#  |    |    |    |    |    |-- images: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |-- images_with_background: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |    |    |    |-- product_id: long (nullable = true)
#  |    |    |    |    |    |-- sticker_id: long (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- video: struct (nullable = true)
#  |    |    |    |    |    |-- access_key: string (nullable = true)
#  |    |    |    |    |    |-- album_id: long (nullable = true)
#  |    |    |    |    |    |-- can_add: long (nullable = true)
#  |    |    |    |    |    |-- comments: long (nullable = true)
#  |    |    |    |    |    |-- content_restricted: long (nullable = true)
#  |    |    |    |    |    |-- date: long (nullable = true)
#  |    |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |    |    |-- first_frame_1024: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_1280: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_130: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_160: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_320: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_4096: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_720: string (nullable = true)
#  |    |    |    |    |    |-- first_frame_800: string (nullable = true)
#  |    |    |    |    |    |-- height: long (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- is_private: long (nullable = true)
#  |    |    |    |    |    |-- live: long (nullable = true)
#  |    |    |    |    |    |-- local_views: long (nullable = true)
#  |    |    |    |    |    |-- owner_id: long (nullable = true)
#  |    |    |    |    |    |-- photo_1280: string (nullable = true)
#  |    |    |    |    |    |-- photo_130: string (nullable = true)
#  |    |    |    |    |    |-- photo_320: string (nullable = true)
#  |    |    |    |    |    |-- photo_640: string (nullable = true)
#  |    |    |    |    |    |-- photo_800: string (nullable = true)
#  |    |    |    |    |    |-- platform: string (nullable = true)
#  |    |    |    |    |    |-- processing: long (nullable = true)
#  |    |    |    |    |    |-- repeat: long (nullable = true)
#  |    |    |    |    |    |-- spectators: long (nullable = true)
#  |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |-- track_code: string (nullable = true)
#  |    |    |    |    |    |-- user_id: long (nullable = true)
#  |    |    |    |    |    |-- views: long (nullable = true)
#  |    |    |    |    |    |-- width: long (nullable = true)
#  |    |    |-- date: long (nullable = true)
#  |    |    |-- final_post: long (nullable = true)
#  |    |    |-- from_id: long (nullable = true)
#  |    |    |-- geo: struct (nullable = true)
#  |    |    |    |-- coordinates: string (nullable = true)
#  |    |    |    |-- place: struct (nullable = true)
#  |    |    |    |    |-- address: string (nullable = true)
#  |    |    |    |    |-- checkins: long (nullable = true)
#  |    |    |    |    |-- city: string (nullable = true)
#  |    |    |    |    |-- country: string (nullable = true)
#  |    |    |    |    |-- created: long (nullable = true)
#  |    |    |    |    |-- icon: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- latitude: double (nullable = true)
#  |    |    |    |    |-- longitude: double (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- type: long (nullable = true)
#  |    |    |    |-- showmap: long (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- owner_id: long (nullable = true)
#  |    |    |-- post_source: struct (nullable = true)
#  |    |    |    |-- data: string (nullable = true)
#  |    |    |    |-- link: struct (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- platform: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- post_type: string (nullable = true)
#  |    |    |-- reply_post_id: long (nullable = true)
#  |    |    |-- signer_id: long (nullable = true)
#  |    |    |-- text: string (nullable = true)
#  |-- copyright: struct (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- link: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |-- date: long (nullable = true)
#  |-- final_post: long (nullable = true)
#  |-- from_id: long (nullable = true)
#  |-- geo: struct (nullable = true)
#  |    |-- coordinates: string (nullable = true)
#  |    |-- place: struct (nullable = true)
#  |    |    |-- address: string (nullable = true)
#  |    |    |-- checkins: long (nullable = true)
#  |    |    |-- city: string (nullable = true)
#  |    |    |-- country: string (nullable = true)
#  |    |    |-- created: long (nullable = true)
#  |    |    |-- icon: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- latitude: double (nullable = true)
#  |    |    |-- longitude: double (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- type: long (nullable = true)
#  |    |-- showmap: long (nullable = true)
#  |    |-- type: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- is_pinned: long (nullable = true)
#  |-- key: string (nullable = true)
#  |-- likes: struct (nullable = true)
#  |    |-- can_like: long (nullable = true)
#  |    |-- can_publish: long (nullable = true)
#  |    |-- count: long (nullable = true)
#  |    |-- user_likes: long (nullable = true)
#  |-- owner_id: long (nullable = true)
#  |-- post_source: struct (nullable = true)
#  |    |-- data: string (nullable = true)
#  |    |-- link: struct (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- platform: string (nullable = true)
#  |    |-- type: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- post_type: string (nullable = true)
#  |-- reposts: struct (nullable = true)
#  |    |-- count: long (nullable = true)
#  |    |-- user_reposted: long (nullable = true)
#  |-- signer_id: long (nullable = true)
#  |-- text: string (nullable = true)
#  |-- unavailable: string (nullable = true)
#  |-- views: struct (nullable = true)
#  |    |-- count: long (nullable = true)

# %%
followers_df.printSchema()
# Out:
# root
#  |-- profile: integer (nullable = true)
#  |-- follower: integer (nullable = true)

# %% [markdown]
# структура followers_posts_df такая же как и posts_df, но рассматривает множество пользователей, а не одну лишь группу ИТМО как во втором случае. Атрибут copy_history из followers_posts_df имеется лишь у записей на стене пользователя, являющихся репостами. Выберем из followers_posts_df лишь те посты, которые являются репостами (на стене пользователя могут быть и собственные записи) и для которых id владельца стены, где размещен пост copy_history[owner_id] = -94, т.е. репосты из группы ИТМО.
# Сгруппируем полученные таким образом посты по их id в группе ИТМО (атрибут copy_history[id]), поставив второй колонкой число постов с данным copy_history[id], что эквивалентно числу пользователей репостнувших запись к себе на стену.

# %%
ur_df = followers_posts_df.select('owner_id', col('copy_history')['id'][0].name('orig_post_id'))\
    .where(col('copy_history')['owner_id'][0] == -94)\
    .withColumnRenamed('owner_id', 'user_id')

# %%
ur_df.groupby('orig_post_id')\
    .agg(F.collect_list('user_id').name('users'))\
    .collect()
# Out:
# [Row(orig_post_id=41424, users=[1475301, 282843035, 172808182]),
#  Row(orig_post_id=42388, users=[180907432]),
#  Row(orig_post_id=39407, users=[8082648, 2031644]),
#  Row(orig_post_id=39719, users=[89417157]),
#  Row(orig_post_id=38963, users=[6591522, 15641504, 172808182, 377805819, 477893414]),
#  Row(orig_post_id=40011, users=[1546152, 1098272, 317799]),
#  Row(orig_post_id=39259, users=[86937823, 159562593, 135556, 28405519, 253204918, 113773552, 15900015, 319622206]),
#  Row(orig_post_id=40084, users=[268247082]),
#  Row(orig_post_id=42009, users=[443525857, 281951154]),
#  Row(orig_post_id=41506, users=[139081799, 29899117, 537403451, 527580876, 527580876]),
#  Row(orig_post_id=38857, users=[484122052]),
#  Row(orig_post_id=38854, users=[484122052]),
#  Row(orig_post_id=40521, users=[418595183]),
#  Row(orig_post_id=40996, users=[344349]),
#  Row(orig_post_id=39082, users=[319622206]),
#  Row(orig_post_id=42691, users=[161500412]),
#  Row(orig_post_id=41039, users=[180907432]),
#  Row(orig_post_id=38754, users=[5567322]),
#  Row(orig_post_id=38818, users=[180907432]),
#  Row(orig_post_id=41402, users=[392929284, 786161, 170536292]),
#  Row(orig_post_id=41535, users=[342841693]),
#  Row(orig_post_id=41917, users=[256973]),
#  Row(orig_post_id=40190, users=[86002]),
#  Row(orig_post_id=42256, users=[56864900, 217400123]),
#  Row(orig_post_id=41912, users=[1533614]),
#  Row(orig_post_id=41721, users=[14834349, 317799, 9334984, 180907432, 44361144, 555633260]),
#  Row(orig_post_id=41521, users=[209943513]),
#  Row(orig_post_id=40585, users=[238291959]),
#  Row(orig_post_id=40432, users=[51735514]),
#  Row(orig_post_id=41046, users=[180907432]),
#  Row(orig_post_id=41369, users=[180907432]),
#  Row(orig_post_id=42234, users=[180907432]),
#  Row(orig_post_id=39515, users=[18467645, 15840290, 4197185, 2031644]),
#  Row(orig_post_id=40100, users=[317799, 483010700]),
#  Row(orig_post_id=39758, users=[3505022, 137035486]),
#  Row(orig_post_id=38960, users=[2547211]),
#  Row(orig_post_id=41659, users=[86002, 153941761]),
#  Row(orig_post_id=40180, users=[14834349, 268247082]),
#  Row(orig_post_id=40839, users=[1548876]),
#  Row(orig_post_id=41200, users=[156758896]),
#  Row(orig_post_id=42482, users=[61439087, 44642738, 178417557, 342841693, 245119117, 89417157, 161891254, 214069421, 135975909, 250268228]),
#  Row(orig_post_id=40145, users=[157728618]),
#  Row(orig_post_id=42020, users=[365885]),
#  Row(orig_post_id=41093, users=[180907432, 84049910]),
#  Row(orig_post_id=456239414, users=[4068532, 5070857, 1548876, 128082542, 502205820, 340764718, 471165, 215847338, 168543860, 255396611]),
#  Row(orig_post_id=39723, users=[1533614]),
#  Row(orig_post_id=40172, users=[2547211]),
#  Row(orig_post_id=456239390, users=[526122695]),
#  Row(orig_post_id=41129, users=[180907432]),
#  Row(orig_post_id=40984, users=[180907432]),
#  Row(orig_post_id=42201, users=[168543860]),
#  Row(orig_post_id=40274, users=[172808182]),
#  Row(orig_post_id=42679, users=[42832710]),
#  Row(orig_post_id=38999, users=[344349]),
#  Row(orig_post_id=40873, users=[317799]),
#  Row(orig_post_id=41266, users=[10339095, 113773552, 986544, 148627607, 18224323, 154665473, 152941256, 415938349, 412594050, 408938851, 446881639, 29885219, 180907432, 118123136, 1431573, 19181714, 18150928, 57183923, 52561412, 63161912, 180187722, 483010700, 466010016, 440454268, 390076321, 446514737, 446514737, 426396104, 524656784, 514384760]),
#  Row(orig_post_id=38876, users=[484122052, 100363682]),
#  Row(orig_post_id=42548, users=[19549000]),
#  Row(orig_post_id=38755, users=[17499681]),
#  Row(orig_post_id=42273, users=[176461282, 2070090, 180907432]),
#  Row(orig_post_id=38751, users=[110861]),
#  Row(orig_post_id=41282, users=[180907432]),
#  Row(orig_post_id=42188, users=[466028583]),
#  Row(orig_post_id=41982, users=[135705506]),
#  Row(orig_post_id=40988, users=[180907432]),
#  Row(orig_post_id=42576, users=[168543860, 168543860]),
#  Row(orig_post_id=42117, users=[488596130]),
#  Row(orig_post_id=38847, users=[180907432, 329472865]),
#  Row(orig_post_id=41525, users=[20232844]),
#  Row(orig_post_id=42397, users=[229227234]),
#  Row(orig_post_id=38767, users=[156713648, 281951154]),
#  Row(orig_post_id=41686, users=[516669490]),
#  Row(orig_post_id=41171, users=[281951154, 180907432]),
#  Row(orig_post_id=42447, users=[275773467]),
#  Row(orig_post_id=41684, users=[43225330]),
#  Row(orig_post_id=39205, users=[10515940]),
#  Row(orig_post_id=41159, users=[281951154, 180907432]),
#  Row(orig_post_id=40384, users=[527580876]),
#  Row(orig_post_id=38968, users=[180907432]),
#  Row(orig_post_id=40780, users=[6591522]),
#  Row(orig_post_id=40301, users=[83076388, 3523889, 2547211]),
#  Row(orig_post_id=456242999, users=[142992667]),
#  Row(orig_post_id=41191, users=[4068532]),
#  Row(orig_post_id=41588, users=[216505726, 23055567]),
#  Row(orig_post_id=40633, users=[415938349, 237894970]),
#  Row(orig_post_id=42508, users=[13805465]),
#  Row(orig_post_id=38972, users=[180907432, 317799]),
#  Row(orig_post_id=42730, users=[71121465, 140186736, 112498659, 134346829]),
#  Row(orig_post_id=39686, users=[204910156, 317799, 26176978, 327904938]),
#  Row(orig_post_id=41952, users=[180907432, 83685448]),
#  Row(orig_post_id=42334, users=[54101707, 1077823, 303931755]),
#  Row(orig_post_id=41708, users=[12143105, 1077823, 329472865, 44361144]),
#  Row(orig_post_id=38871, users=[484122052, 5567322]),
#  Row(orig_post_id=39682, users=[81515026, 222761898, 1548876, 204910156, 239244387]),
#  Row(orig_post_id=41030, users=[317799, 1077823]),
#  Row(orig_post_id=40336, users=[106239055]),
#  Row(orig_post_id=40742, users=[217400123]),
#  Row(orig_post_id=456239329, users=[11110531]),
#  Row(orig_post_id=41194, users=[1533614, 147134482]),
#  Row(orig_post_id=41311, users=[180907432]),
#  Row(orig_post_id=40999, users=[2547211]),
#  Row(orig_post_id=41337, users=[180907432]),
#  Row(orig_post_id=40929, users=[147134482]),
#  Row(orig_post_id=42270, users=[43225330]),
#  Row(orig_post_id=42507, users=[44361144, 510323128]),
#  Row(orig_post_id=41218, users=[26739609, 281951154]),
#  Row(orig_post_id=39948, users=[180907432]),
#  Row(orig_post_id=39282, users=[59949877, 180907432]),
#  Row(orig_post_id=41706, users=[256973, 317799]),
#  Row(orig_post_id=39757, users=[1533614, 317799]),
#  Row(orig_post_id=42265, users=[317799]),
#  Row(orig_post_id=39954, users=[227562771]),
#  Row(orig_post_id=41331, users=[180907432, 217400123]),
#  Row(orig_post_id=42714, users=[164820203]),
#  Row(orig_post_id=41712, users=[4068532, 121608397]),
#  Row(orig_post_id=39742, users=[15840290, 2031644]),
#  Row(orig_post_id=38823, users=[12403553]),
#  Row(orig_post_id=38867, users=[52707846, 484122052]),
#  Row(orig_post_id=40794, users=[317799, 180907432]),
#  Row(orig_post_id=41945, users=[156713648, 2070090]),
#  Row(orig_post_id=39079, users=[2547211]),
#  Row(orig_post_id=42669, users=[431298462]),
#  Row(orig_post_id=38877, users=[180907432]),
#  Row(orig_post_id=38748, users=[180907432]),
#  Row(orig_post_id=41289, users=[180907432, 48034462]),
#  Row(orig_post_id=40994, users=[143207077]),
#  Row(orig_post_id=42505, users=[359477755]),
#  Row(orig_post_id=38859, users=[484122052]),
#  Row(orig_post_id=41602, users=[4068532]),
#  Row(orig_post_id=456239423, users=[13967063]),
#  Row(orig_post_id=40572, users=[307190744, 543831937]),
#  Row(orig_post_id=41685, users=[180907432]),
#  Row(orig_post_id=41064, users=[180907432, 189933794, 1077823]),
#  Row(orig_post_id=40480, users=[55699584, 27832682, 233976767]),
#  Row(orig_post_id=38738, users=[19289915]),
#  Row(orig_post_id=39749, users=[34157796, 532297882]),
#  Row(orig_post_id=38730, users=[157728618, 19289915, 180907432]),
#  Row(orig_post_id=40856, users=[188913529, 148521296]),
#  Row(orig_post_id=38915, users=[2923196, 317799, 59949877, 39823750]),
#  Row(orig_post_id=42577, users=[156278470, 2923196]),
#  Row(orig_post_id=39856, users=[3505022, 1546152]),
#  Row(orig_post_id=41676, users=[55930167]),
#  Row(orig_post_id=40401, users=[1546152]),
#  Row(orig_post_id=38995, users=[147054031]),
#  Row(orig_post_id=42186, users=[180907432, 154091441, 43225330]),
#  Row(orig_post_id=41313, users=[180907432]),
#  Row(orig_post_id=41704, users=[275773467]),
#  Row(orig_post_id=38858, users=[484122052]),
#  Row(orig_post_id=41713, users=[4068532]),
#  Row(orig_post_id=41140, users=[180181348]),
#  Row(orig_post_id=39748, users=[44361144, 55699584, 388899559]),
#  Row(orig_post_id=40683, users=[180907432, 268247082]),
#  Row(orig_post_id=40118, users=[373190294]),
#  Row(orig_post_id=38814, users=[180907432]),
#  Row(orig_post_id=41120, users=[516010906]),
#  Row(orig_post_id=38764, users=[925142]),
#  Row(orig_post_id=40712, users=[100365912]),
#  Row(orig_post_id=40972, users=[180907432]),
#  Row(orig_post_id=41207, users=[183202785, 5264415, 317799, 2070090, 180907432, 217400123]),
#  Row(orig_post_id=41059, users=[189933794, 1077823]),
#  Row(orig_post_id=41188, users=[180907432, 4068532]),
#  Row(orig_post_id=41329, users=[89417157]),
#  Row(orig_post_id=39009, users=[86002, 2547211]),
#  Row(orig_post_id=39917, users=[34157796]),
#  Row(orig_post_id=40090, users=[3505022, 425920, 5264415, 237894970, 4068532, 157728618, 185035504, 11301324, 527580876]),
#  Row(orig_post_id=40320, users=[26176978]),
#  Row(orig_post_id=38881, users=[180907432]),
#  Row(orig_post_id=40924, users=[180907432]),
#  Row(orig_post_id=41127, users=[180181348, 317799, 249534514]),
#  Row(orig_post_id=40510, users=[329472865]),
#  Row(orig_post_id=41725, users=[37127521]),
#  Row(orig_post_id=40908, users=[4068532, 4068532]),
#  Row(orig_post_id=41108, users=[180907432, 344349, 251113524, 237894970]),
#  Row(orig_post_id=42041, users=[378085567]),
#  Row(orig_post_id=40592, users=[92556354]),
#  Row(orig_post_id=40606, users=[44748]),
#  Row(orig_post_id=39916, users=[417950963]),
#  Row(orig_post_id=42316, users=[56864900, 192932783, 319622206]),
#  Row(orig_post_id=42663, users=[63161912]),
#  Row(orig_post_id=38907, users=[159562593, 255396611]),
#  Row(orig_post_id=39374, users=[18467645, 2547211]),
#  Row(orig_post_id=41468, users=[53027, 8050972, 163562629, 85370197, 113773552, 172158253, 4068532, 51059749, 317799, 69693, 370402094, 406176994, 1994419, 2070090, 151172973, 11456725, 242175937, 50551, 19549000, 143597561, 158709203, 19471, 91390312, 128527581, 380317476]),
#  Row(orig_post_id=41968, users=[5264415, 282843035]),
#  Row(orig_post_id=42163, users=[2070090]),
#  Row(orig_post_id=40915, users=[317799]),
#  Row(orig_post_id=41855, users=[278100021, 88359321]),
#  Row(orig_post_id=41151, users=[180907432]),
#  Row(orig_post_id=41906, users=[104119888]),
#  Row(orig_post_id=39696, users=[19549000]),
#  Row(orig_post_id=42152, users=[180907432]),
#  Row(orig_post_id=39294, users=[18467645, 156632195, 52526067, 2923196]),
#  Row(orig_post_id=40735, users=[180907432]),
#  Row(orig_post_id=41316, users=[180907432, 4068532]),
#  Row(orig_post_id=42161, users=[2004962, 2547211]),
#  Row(orig_post_id=456242467, users=[3290903]),
#  Row(orig_post_id=38862, users=[484122052]),
#  Row(orig_post_id=41029, users=[189933794, 268247082]),
#  Row(orig_post_id=41451, users=[307190744, 268813604]),
#  Row(orig_post_id=38740, users=[32985413, 68122700, 37127521, 19289915, 180907432, 83076388, 300687993, 496979563]),
#  Row(orig_post_id=40661, users=[1120826]),
#  Row(orig_post_id=41838, users=[157728618, 254495929]),
#  Row(orig_post_id=38791, users=[311384313]),
#  Row(orig_post_id=41679, users=[3615975, 466854889]),
#  Row(orig_post_id=40228, users=[205305143]),
#  Row(orig_post_id=40134, users=[268247082]),
#  Row(orig_post_id=41995, users=[526296593]),
#  Row(orig_post_id=41305, users=[1475301]),
#  Row(orig_post_id=38904, users=[2547211]),
#  Row(orig_post_id=38957, users=[110861, 477893414]),
#  Row(orig_post_id=41891, users=[254495929]),
#  Row(orig_post_id=38897, users=[72396326]),
#  Row(orig_post_id=42452, users=[192344013]),
#  Row(orig_post_id=39659, users=[104698779]),
#  Row(orig_post_id=42347, users=[4068532]),
#  Row(orig_post_id=41546, users=[157272120, 256973, 261917672, 82668971, 88359321, 172808182]),
#  Row(orig_post_id=40569, users=[409283061]),
#  Row(orig_post_id=41297, users=[180907432]),
#  Row(orig_post_id=39868, users=[18467645]),
#  Row(orig_post_id=40427, users=[53368685])]

# %% [markdown]
# # Step 4
# find emoticons in posts and their comments (negative, positive, neutral)

# %%
# download emoji library
import sys
# !{sys.executable} -m pip install --user --trusted-host pypi-registry.supplementary-services.svc.cluster.local --index http://pypi-registry.supplementary-services.svc.cluster.local:8080 emoji
        
import emoji
from pyspark.sql.types import ArrayType, StringType
import pandas as pd
# Out:
# Looking in indexes: http://pypi-registry.supplementary-services.svc.cluster.local:8080
# Requirement already satisfied: emoji in /opt/conda/lib/python3.8/site-packages (1.2.0)

# %%
@udf(returnType=ArrayType(StringType())) 
def emojies_in_text(text):
    results = []
    for match in emoji.get_emoji_regexp().finditer(text):
        results.append(match.group())
    return results

emojies_in_posts = posts_df\
    .where("text <> ''").select("id", 'text')\
    .withColumn("emojies", emojies_in_text(col("text")))\
    .where("size(emojies) > 0")\
    .select("id", F.explode("emojies").alias("emoji"))\
    .groupBy("emoji")\
    .agg(F.count("id").alias("count"),F.countDistinct("id").alias("frequency"))\
    .withColumn("average_count_by_post", col("count") / col("frequency"))\
    .withColumn("difference", col("count") - col("frequency"))

# %%
emojies_in_posts\
    .select("emoji", "count")\
    .orderBy(F.desc("count"))\
    .limit(10)\
    .collect()
# Out:
# [Row(emoji='🔥', count=76),
#  Row(emoji='⚡', count=68),
#  Row(emoji='📍', count=63),
#  Row(emoji='🚀', count=50),
#  Row(emoji='❤', count=47),
#  Row(emoji='❗', count=45),
#  Row(emoji='🔵', count=40),
#  Row(emoji='⬇', count=40),
#  Row(emoji='✔', count=40),
#  Row(emoji='💙', count=38)]

# %%
emojies_in_posts\
    .select("emoji", "difference")\
    .orderBy(F.desc("difference"))\
    .limit(5)\
    .collect()
# Out:
# [Row(emoji='✔', difference=31),
#  Row(emoji='❗', difference=25),
#  Row(emoji='📍', difference=24),
#  Row(emoji='⬇', difference=24),
#  Row(emoji='🔵', difference=23)]

# %%
emojies_in_posts\
    .select("emoji", "average_count_by_post")\
    .orderBy(F.desc("average_count_by_post"))\
    .limit(5)\
    .collect()
# Out:
# [Row(emoji='✔', average_count_by_post=4.444444444444445),
#  Row(emoji='🔹', average_count_by_post=4.285714285714286),
#  Row(emoji='▪', average_count_by_post=4.2),
#  Row(emoji='✒', average_count_by_post=3.5),
#  Row(emoji='🔘', average_count_by_post=3.0)]

# %% [markdown]
# # Task 5
# Probable “fans”. Find for each user the top 10 other users whose posts this user likes.

# %%
followers_posts_likes_df.printSchema()
#itemId = PostID - уникальный номер поста
#ownerId - id стены, где пост размещен
#likerId - ID того, кто ставит лайк
# Out:
# root
#  |-- itemType: string (nullable = true)
#  |-- ownerId: integer (nullable = true)
#  |-- itemId: integer (nullable = true)
#  |-- likerId: integer (nullable = true)

# %%
def fans_of(user):
    return followers_posts_likes_df.groupBy("likerId", "ownerId")\
        .agg(F.count("ownerId").name("likes"))\
        .where('ownerId == {}'.format(user))\
        .withColumnRenamed("likerId", 'fan')\
        .orderBy('likes', ascending = False)\
        .limit(10)

# %%
df1 = fans_of(27419)
df1.show()
# Out:
# +---------+-------+-----+
# |      fan|ownerId|likes|
# +---------+-------+-----+
# |  1925168|  27419|    6|
# |     9383|  27419|    4|
# |529276371|  27419|    4|
# |  6866116|  27419|    3|
# |    24147|  27419|    3|
# | 95884146|  27419|    3|
# |291831320|  27419|    3|
# |100187585|  27419|    3|
# |  1622246|  27419|    3|
# |   422720|  27419|    3|
# +---------+-------+-----+

# %%
dfTop_1 = followers_posts_likes_df.groupBy('ownerId', 'likerId')\
    .agg(F.count('likerId').name('count'))\
    .withColumn("rn", row_number().over(w))\
    .where(col("rn") < 11)

# %%
dfTop_1.collect()
# Out:
# [Row(ownerId=13832, likerId=216785, count=14, rn=1),
#  Row(ownerId=13832, likerId=135660, count=13, rn=2),
#  Row(ownerId=13832, likerId=71831300, count=10, rn=3),
#  Row(ownerId=13832, likerId=218958, count=6, rn=4),
#  Row(ownerId=13832, likerId=155630, count=5, rn=5),
#  Row(ownerId=13832, likerId=14964847, count=5, rn=6),
#  Row(ownerId=13832, likerId=25211791, count=5, rn=7),
#  Row(ownerId=13832, likerId=519411613, count=5, rn=8),
#  Row(ownerId=13832, likerId=17661, count=4, rn=9),
#  Row(ownerId=13832, likerId=97492, count=3, rn=10),
#  Row(ownerId=246326, likerId=115014784, count=4, rn=1),
#  Row(ownerId=246326, likerId=17755643, count=2, rn=2),
#  Row(ownerId=246326, likerId=262219467, count=2, rn=3),
#  Row(ownerId=246326, likerId=12899, count=1, rn=4),
#  Row(ownerId=246326, likerId=46467, count=1, rn=5),
#  Row(ownerId=246326, likerId=67494, count=1, rn=6),
#  Row(ownerId=246326, likerId=198207, count=1, rn=7),
#  Row(ownerId=246326, likerId=588702, count=1, rn=8),
#  Row(ownerId=246326, likerId=1192515, count=1, rn=9),
#  Row(ownerId=246326, likerId=1524196, count=1, rn=10),
#  Row(ownerId=370123, likerId=67627959, count=14, rn=1),
#  Row(ownerId=370123, likerId=311762299, count=14, rn=2),
#  Row(ownerId=370123, likerId=319650820, count=14, rn=3),
#  Row(ownerId=370123, likerId=200649786, count=12, rn=4),
#  Row(ownerId=370123, likerId=321977727, count=11, rn=5),
#  Row(ownerId=370123, likerId=991268, count=10, rn=6),
#  Row(ownerId=370123, likerId=1029475, count=10, rn=7),
#  Row(ownerId=370123, likerId=24201636, count=10, rn=8),
#  Row(ownerId=370123, likerId=280374158, count=10, rn=9),
#  Row(ownerId=370123, likerId=104643999, count=9, rn=10),
#  Row(ownerId=398172, likerId=24060466, count=14, rn=1),
#  Row(ownerId=398172, likerId=41126639, count=11, rn=2),
#  Row(ownerId=398172, likerId=37150388, count=8, rn=3),
#  Row(ownerId=398172, likerId=292869793, count=8, rn=4),
#  Row(ownerId=398172, likerId=683068, count=7, rn=5),
#  Row(ownerId=398172, likerId=2030118, count=7, rn=6),
#  Row(ownerId=398172, likerId=1145638, count=6, rn=7),
#  Row(ownerId=398172, likerId=248500030, count=5, rn=8),
#  Row(ownerId=398172, likerId=329021, count=4, rn=9),
#  Row(ownerId=398172, likerId=4909104, count=4, rn=10),
#  Row(ownerId=873551, likerId=72933312, count=3, rn=1),
#  Row(ownerId=873551, likerId=387584, count=2, rn=2),
#  Row(ownerId=873551, likerId=6695205, count=2, rn=3),
#  Row(ownerId=873551, likerId=540327821, count=2, rn=4),
#  Row(ownerId=873551, likerId=2341170, count=1, rn=5),
#  Row(ownerId=873551, likerId=3275143, count=1, rn=6),
#  Row(ownerId=873551, likerId=3501721, count=1, rn=7),
#  Row(ownerId=873551, likerId=4669045, count=1, rn=8),
#  Row(ownerId=873551, likerId=9366776, count=1, rn=9),
#  Row(ownerId=873551, likerId=17030943, count=1, rn=10),
#  Row(ownerId=1318440, likerId=240120, count=2, rn=1),
#  Row(ownerId=1318440, likerId=310992, count=2, rn=2),
#  Row(ownerId=1318440, likerId=13077470, count=2, rn=3),
#  Row(ownerId=1318440, likerId=16581819, count=2, rn=4),
#  Row(ownerId=1318440, likerId=173920762, count=2, rn=5),
#  Row(ownerId=1318440, likerId=376425, count=1, rn=6),
#  Row(ownerId=1318440, likerId=1008203, count=1, rn=7),
#  Row(ownerId=1318440, likerId=1730358, count=1, rn=8),
#  Row(ownerId=1318440, likerId=9696274, count=1, rn=9),
#  Row(ownerId=1318440, likerId=9829230, count=1, rn=10),
#  Row(ownerId=3104457, likerId=12200731, count=2, rn=1),
#  Row(ownerId=3104457, likerId=279678, count=1, rn=2),
#  Row(ownerId=3104457, likerId=1835601, count=1, rn=3),
#  Row(ownerId=3104457, likerId=3698830, count=1, rn=4),
#  Row(ownerId=3104457, likerId=6624583, count=1, rn=5),
#  Row(ownerId=3104457, likerId=12933148, count=1, rn=6),
#  Row(ownerId=3104457, likerId=13950733, count=1, rn=7),
#  Row(ownerId=3104457, likerId=20091758, count=1, rn=8),
#  Row(ownerId=3104457, likerId=27113664, count=1, rn=9),
#  Row(ownerId=3104457, likerId=29239296, count=1, rn=10),
#  Row(ownerId=3398212, likerId=88336671, count=72, rn=1),
#  Row(ownerId=3398212, likerId=7397386, count=52, rn=2),
#  Row(ownerId=3398212, likerId=73758823, count=51, rn=3),
#  Row(ownerId=3398212, likerId=5983506, count=31, rn=4),
#  Row(ownerId=3398212, likerId=65247699, count=26, rn=5),
#  Row(ownerId=3398212, likerId=16516222, count=24, rn=6),
#  Row(ownerId=3398212, likerId=266287142, count=24, rn=7),
#  Row(ownerId=3398212, likerId=207678756, count=23, rn=8),
#  Row(ownerId=3398212, likerId=2807094, count=21, rn=9),
#  Row(ownerId=3398212, likerId=187552739, count=19, rn=10),
#  Row(ownerId=4239819, likerId=63492699, count=6, rn=1),
#  Row(ownerId=4239819, likerId=8169701, count=3, rn=2),
#  Row(ownerId=4239819, likerId=27166769, count=3, rn=3),
#  Row(ownerId=4239819, likerId=475624, count=2, rn=4),
#  Row(ownerId=4239819, likerId=2659578, count=2, rn=5),
#  Row(ownerId=4239819, likerId=24384912, count=2, rn=6),
#  Row(ownerId=4239819, likerId=644571, count=1, rn=7),
#  Row(ownerId=4239819, likerId=713505, count=1, rn=8),
#  Row(ownerId=4239819, likerId=1104964, count=1, rn=9),
#  Row(ownerId=4239819, likerId=1116419, count=1, rn=10),
#  Row(ownerId=6386424, likerId=6386424, count=17, rn=1),
#  Row(ownerId=6386424, likerId=27979568, count=17, rn=2),
#  Row(ownerId=6386424, likerId=16782330, count=14, rn=3),
#  Row(ownerId=6386424, likerId=315365828, count=13, rn=4),
#  Row(ownerId=6386424, likerId=1639573, count=11, rn=5),
#  Row(ownerId=6386424, likerId=2852181, count=9, rn=6),
#  Row(ownerId=6386424, likerId=16259684, count=9, rn=7),
#  Row(ownerId=6386424, likerId=18842772, count=9, rn=8),
#  Row(ownerId=6386424, likerId=180427458, count=9, rn=9),
#  Row(ownerId=6386424, likerId=7053789, count=7, rn=10),
#  Row(ownerId=7164436, likerId=22752, count=1, rn=1),
#  Row(ownerId=7164436, likerId=256392, count=1, rn=2),
#  Row(ownerId=7164436, likerId=322212, count=1, rn=3),
#  Row(ownerId=7164436, likerId=335787, count=1, rn=4),
#  Row(ownerId=7164436, likerId=783007, count=1, rn=5),
#  Row(ownerId=7164436, likerId=1071484, count=1, rn=6),
#  Row(ownerId=7164436, likerId=1833686, count=1, rn=7),
#  Row(ownerId=7164436, likerId=2232553, count=1, rn=8),
#  Row(ownerId=7164436, likerId=2942773, count=1, rn=9),
#  Row(ownerId=7164436, likerId=3106030, count=1, rn=10),
#  Row(ownerId=7386340, likerId=7386340, count=3, rn=1),
#  Row(ownerId=7386340, likerId=95099535, count=1, rn=2),
#  Row(ownerId=7386340, likerId=429143226, count=1, rn=3),
#  Row(ownerId=7386340, likerId=539922972, count=1, rn=4),
#  Row(ownerId=8082648, likerId=109474, count=2, rn=1),
#  Row(ownerId=8082648, likerId=84265251, count=2, rn=2),
#  Row(ownerId=8082648, likerId=467463, count=1, rn=3),
#  Row(ownerId=8082648, likerId=650221, count=1, rn=4),
#  Row(ownerId=8082648, likerId=831972, count=1, rn=5),
#  Row(ownerId=8082648, likerId=30238712, count=1, rn=6),
#  Row(ownerId=8082648, likerId=33799905, count=1, rn=7),
#  Row(ownerId=8082648, likerId=49812846, count=1, rn=8),
#  Row(ownerId=8082648, likerId=104732324, count=1, rn=9),
#  Row(ownerId=8082648, likerId=107465630, count=1, rn=10),
#  Row(ownerId=13320757, likerId=19928632, count=23, rn=1),
#  Row(ownerId=13320757, likerId=89819884, count=21, rn=2),
#  Row(ownerId=13320757, likerId=215209, count=19, rn=3),
#  Row(ownerId=13320757, likerId=18812669, count=17, rn=4),
#  Row(ownerId=13320757, likerId=242666011, count=17, rn=5),
#  Row(ownerId=13320757, likerId=1479942, count=14, rn=6),
#  Row(ownerId=13320757, likerId=197728815, count=12, rn=7),
#  Row(ownerId=13320757, likerId=337565190, count=12, rn=8),
#  Row(ownerId=13320757, likerId=416504, count=11, rn=9),
#  Row(ownerId=13320757, likerId=1519851, count=11, rn=10),
#  Row(ownerId=25043904, likerId=273184341, count=115, rn=1),
#  Row(ownerId=25043904, likerId=115203112, count=113, rn=2),
#  Row(ownerId=25043904, likerId=96571222, count=111, rn=3),
#  Row(ownerId=25043904, likerId=337544046, count=109, rn=4),
#  Row(ownerId=25043904, likerId=10508509, count=87, rn=5),
#  Row(ownerId=25043904, likerId=40984055, count=82, rn=6),
#  Row(ownerId=25043904, likerId=398870929, count=72, rn=7),
#  Row(ownerId=25043904, likerId=155877219, count=70, rn=8),
#  Row(ownerId=25043904, likerId=58498090, count=63, rn=9),
#  Row(ownerId=25043904, likerId=134910514, count=62, rn=10),
#  Row(ownerId=33691649, likerId=219921356, count=2, rn=1),
#  Row(ownerId=38961593, likerId=267394849, count=2, rn=1),
#  Row(ownerId=38961593, likerId=46287656, count=1, rn=2),
#  Row(ownerId=38961593, likerId=99793318, count=1, rn=3),
#  Row(ownerId=38961593, likerId=149251732, count=1, rn=4),
#  Row(ownerId=38961593, likerId=200431980, count=1, rn=5),
#  Row(ownerId=38961593, likerId=222471495, count=1, rn=6),
#  Row(ownerId=38961593, likerId=225076175, count=1, rn=7),
#  Row(ownerId=38961593, likerId=411381353, count=1, rn=8),
#  Row(ownerId=38961593, likerId=508813871, count=1, rn=9),
#  Row(ownerId=38961593, likerId=526476683, count=1, rn=10),
#  Row(ownerId=45846701, likerId=156324, count=6, rn=1),
#  Row(ownerId=45846701, likerId=52010837, count=5, rn=2),
#  Row(ownerId=45846701, likerId=187353523, count=5, rn=3),
#  Row(ownerId=45846701, likerId=190859397, count=5, rn=4),
#  Row(ownerId=45846701, likerId=201744017, count=5, rn=5),
#  Row(ownerId=45846701, likerId=234985893, count=5, rn=6),
#  Row(ownerId=45846701, likerId=183421228, count=4, rn=7),
#  Row(ownerId=45846701, likerId=209366145, count=4, rn=8),
#  Row(ownerId=45846701, likerId=787360, count=3, rn=9),
#  Row(ownerId=45846701, likerId=10643521, count=3, rn=10),
#  Row(ownerId=46171914, likerId=347165527, count=3, rn=1),
#  Row(ownerId=46171914, likerId=651816, count=2, rn=2),
#  Row(ownerId=46171914, likerId=3165140, count=2, rn=3),
#  Row(ownerId=46171914, likerId=9365657, count=2, rn=4),
#  Row(ownerId=46171914, likerId=160657, count=1, rn=5),
#  Row(ownerId=46171914, likerId=162638, count=1, rn=6),
#  Row(ownerId=46171914, likerId=295438, count=1, rn=7),
#  Row(ownerId=46171914, likerId=484377, count=1, rn=8),
#  Row(ownerId=46171914, likerId=577445, count=1, rn=9),
#  Row(ownerId=46171914, likerId=3171545, count=1, rn=10),
#  Row(ownerId=46907886, likerId=186814070, count=3, rn=1),
#  Row(ownerId=46907886, likerId=281464336, count=2, rn=2),
#  Row(ownerId=46907886, likerId=316289307, count=2, rn=3),
#  Row(ownerId=46907886, likerId=54097149, count=1, rn=4),
#  Row(ownerId=46907886, likerId=67644062, count=1, rn=5),
#  Row(ownerId=46907886, likerId=113513282, count=1, rn=6),
#  Row(ownerId=46907886, likerId=167396928, count=1, rn=7),
#  Row(ownerId=46907886, likerId=169803735, count=1, rn=8),
#  Row(ownerId=46907886, likerId=171418081, count=1, rn=9),
#  Row(ownerId=46907886, likerId=207184568, count=1, rn=10),
#  Row(ownerId=49848562, likerId=1261398, count=2, rn=1),
#  Row(ownerId=49848562, likerId=27259207, count=2, rn=2),
#  Row(ownerId=49848562, likerId=70222592, count=2, rn=3),
#  Row(ownerId=49848562, likerId=76058269, count=2, rn=4),
#  Row(ownerId=49848562, likerId=78492239, count=2, rn=5),
#  Row(ownerId=49848562, likerId=93074430, count=2, rn=6),
#  Row(ownerId=49848562, likerId=100206616, count=2, rn=7),
#  Row(ownerId=49848562, likerId=113105730, count=2, rn=8),
#  Row(ownerId=49848562, likerId=145489535, count=2, rn=9),
#  Row(ownerId=49848562, likerId=153245526, count=2, rn=10),
#  Row(ownerId=54142521, likerId=50084668, count=1, rn=1),
#  Row(ownerId=54142521, likerId=322984069, count=1, rn=2),
#  Row(ownerId=54142521, likerId=511167713, count=1, rn=3),
#  Row(ownerId=63394933, likerId=63394933, count=6, rn=1),
#  Row(ownerId=63394933, likerId=124756089, count=6, rn=2),
#  Row(ownerId=63394933, likerId=206758102, count=6, rn=3),
#  Row(ownerId=63394933, likerId=329963030, count=6, rn=4),
#  Row(ownerId=63394933, likerId=389032067, count=6, rn=5),
#  Row(ownerId=63394933, likerId=32629559, count=5, rn=6),
#  Row(ownerId=63394933, likerId=42068086, count=5, rn=7),
#  Row(ownerId=63394933, likerId=70162004, count=5, rn=8),
#  Row(ownerId=63394933, likerId=141150134, count=5, rn=9),
#  Row(ownerId=63394933, likerId=142089196, count=5, rn=10),
#  Row(ownerId=67632864, likerId=152781657, count=7, rn=1),
#  Row(ownerId=67632864, likerId=291317910, count=2, rn=2),
#  Row(ownerId=67632864, likerId=356401159, count=2, rn=3),
#  Row(ownerId=67632864, likerId=12140336, count=1, rn=4),
#  Row(ownerId=67632864, likerId=18404042, count=1, rn=5),
#  Row(ownerId=67632864, likerId=20610109, count=1, rn=6),
#  Row(ownerId=67632864, likerId=44345379, count=1, rn=7),
#  Row(ownerId=67632864, likerId=76993430, count=1, rn=8),
#  Row(ownerId=67632864, likerId=172582485, count=1, rn=9),
#  Row(ownerId=67632864, likerId=242303498, count=1, rn=10),
#  Row(ownerId=67896898, likerId=4098656, count=1, rn=1),
#  Row(ownerId=67896898, likerId=9173202, count=1, rn=2),
#  Row(ownerId=67896898, likerId=10386225, count=1, rn=3),
#  Row(ownerId=67896898, likerId=23810956, count=1, rn=4),
#  Row(ownerId=67896898, likerId=23958294, count=1, rn=5),
#  Row(ownerId=67896898, likerId=27290390, count=1, rn=6),
#  Row(ownerId=67896898, likerId=33996621, count=1, rn=7),
#  Row(ownerId=67896898, likerId=34187492, count=1, rn=8),
#  Row(ownerId=67896898, likerId=43358085, count=1, rn=9),
#  Row(ownerId=67896898, likerId=43519896, count=1, rn=10),
#  Row(ownerId=75689632, likerId=158136227, count=1, rn=1),
#  Row(ownerId=80734900, likerId=467513, count=1, rn=1),
#  Row(ownerId=80734900, likerId=500276, count=1, rn=2),
#  Row(ownerId=80734900, likerId=21715191, count=1, rn=3),
#  Row(ownerId=80734900, likerId=21846441, count=1, rn=4),
#  Row(ownerId=80734900, likerId=68203999, count=1, rn=5),
#  Row(ownerId=80734900, likerId=69983610, count=1, rn=6),
#  Row(ownerId=80734900, likerId=72135838, count=1, rn=7),
#  Row(ownerId=80734900, likerId=76631510, count=1, rn=8),
#  Row(ownerId=80734900, likerId=82095152, count=1, rn=9),
#  Row(ownerId=80734900, likerId=83686530, count=1, rn=10),
#  Row(ownerId=90898752, likerId=337058649, count=4, rn=1),
#  Row(ownerId=90898752, likerId=24784121, count=3, rn=2),
#  Row(ownerId=90898752, likerId=464282824, count=3, rn=3),
#  Row(ownerId=90898752, likerId=495381285, count=3, rn=4),
#  Row(ownerId=90898752, likerId=168438070, count=2, rn=5),
#  Row(ownerId=90898752, likerId=176063238, count=2, rn=6),
#  Row(ownerId=90898752, likerId=271542272, count=2, rn=7),
#  Row(ownerId=90898752, likerId=474311883, count=2, rn=8),
#  Row(ownerId=90898752, likerId=4510973, count=1, rn=9),
#  Row(ownerId=90898752, likerId=25107372, count=1, rn=10),
#  Row(ownerId=138935816, likerId=491331369, count=5, rn=1),
#  Row(ownerId=138935816, likerId=384022970, count=4, rn=2),
#  Row(ownerId=138935816, likerId=418551013, count=4, rn=3),
#  Row(ownerId=138935816, likerId=449955054, count=4, rn=4),
#  Row(ownerId=138935816, likerId=153077727, count=3, rn=5),
#  Row(ownerId=138935816, likerId=530444547, count=3, rn=6),
#  Row(ownerId=138935816, likerId=93822145, count=2, rn=7),
#  Row(ownerId=138935816, likerId=154286918, count=2, rn=8),
#  Row(ownerId=138935816, likerId=169860752, count=2, rn=9),
#  Row(ownerId=138935816, likerId=182925971, count=2, rn=10),
#  Row(ownerId=143514062, likerId=174309144, count=2, rn=1),
#  Row(ownerId=143514062, likerId=319162202, count=2, rn=2),
#  Row(ownerId=143514062, likerId=381985171, count=2, rn=3),
#  Row(ownerId=143514062, likerId=548177949, count=2, rn=4),
#  Row(ownerId=143514062, likerId=139844675, count=1, rn=5),
#  Row(ownerId=143514062, likerId=141361365, count=1, rn=6),
#  Row(ownerId=143514062, likerId=143127874, count=1, rn=7),
#  Row(ownerId=143514062, likerId=148361564, count=1, rn=8),
#  Row(ownerId=143514062, likerId=152826818, count=1, rn=9),
#  Row(ownerId=143514062, likerId=152909081, count=1, rn=10),
#  Row(ownerId=146446605, likerId=136183064, count=2, rn=1),
#  Row(ownerId=146446605, likerId=157785840, count=2, rn=2),
#  Row(ownerId=146446605, likerId=269109356, count=1, rn=3),
#  Row(ownerId=146446605, likerId=415397361, count=1, rn=4),
#  Row(ownerId=153123605, likerId=405143020, count=5, rn=1),
#  Row(ownerId=153123605, likerId=17707427, count=4, rn=2),
#  Row(ownerId=153123605, likerId=54626624, count=4, rn=3),
#  Row(ownerId=153123605, likerId=67147575, count=4, rn=4),
#  Row(ownerId=153123605, likerId=170163005, count=4, rn=5),
#  Row(ownerId=153123605, likerId=33207029, count=3, rn=6),
#  Row(ownerId=153123605, likerId=56886316, count=3, rn=7),
#  Row(ownerId=153123605, likerId=136745959, count=3, rn=8),
#  Row(ownerId=153123605, likerId=147818550, count=3, rn=9),
#  Row(ownerId=153123605, likerId=151782038, count=3, rn=10),
#  Row(ownerId=155296651, likerId=155296651, count=2, rn=1),
#  Row(ownerId=155296651, likerId=446047347, count=2, rn=2),
#  Row(ownerId=160555450, likerId=160555450, count=2, rn=1),
#  Row(ownerId=160555450, likerId=162044989, count=2, rn=2),
#  Row(ownerId=160555450, likerId=167812592, count=2, rn=3),
#  Row(ownerId=160555450, likerId=198704993, count=2, rn=4),
#  Row(ownerId=160555450, likerId=221758806, count=2, rn=5),
#  Row(ownerId=160555450, likerId=242291059, count=2, rn=6),
#  Row(ownerId=160555450, likerId=253442170, count=2, rn=7),
#  Row(ownerId=160555450, likerId=299195413, count=2, rn=8),
#  Row(ownerId=160555450, likerId=315683150, count=2, rn=9),
#  Row(ownerId=160555450, likerId=360656561, count=2, rn=10),
#  Row(ownerId=160640874, likerId=77458404, count=3, rn=1),
#  Row(ownerId=160640874, likerId=13215597, count=2, rn=2),
#  Row(ownerId=160640874, likerId=13957781, count=2, rn=3),
#  Row(ownerId=160640874, likerId=32590662, count=2, rn=4),
#  Row(ownerId=160640874, likerId=33052305, count=2, rn=5),
#  Row(ownerId=160640874, likerId=37673387, count=2, rn=6),
#  Row(ownerId=160640874, likerId=40032286, count=2, rn=7),
#  Row(ownerId=160640874, likerId=62720393, count=2, rn=8),
#  Row(ownerId=160640874, likerId=65716747, count=2, rn=9),
#  Row(ownerId=160640874, likerId=83636377, count=2, rn=10),
#  Row(ownerId=161043190, likerId=134320172, count=3, rn=1),
#  Row(ownerId=161043190, likerId=137255725, count=3, rn=2),
#  Row(ownerId=161043190, likerId=146162460, count=3, rn=3),
#  Row(ownerId=161043190, likerId=161043190, count=3, rn=4),
#  Row(ownerId=161043190, likerId=202900653, count=3, rn=5),
#  Row(ownerId=161043190, likerId=245262840, count=3, rn=6),
#  Row(ownerId=161043190, likerId=345551423, count=3, rn=7),
#  Row(ownerId=161043190, likerId=348902652, count=3, rn=8),
#  Row(ownerId=161043190, likerId=355829352, count=3, rn=9),
#  Row(ownerId=161043190, likerId=386460055, count=3, rn=10),
#  Row(ownerId=163390848, likerId=371193032, count=191, rn=1),
#  Row(ownerId=163390848, likerId=176719577, count=63, rn=2),
#  Row(ownerId=163390848, likerId=361099540, count=41, rn=3),
#  Row(ownerId=163390848, likerId=47258889, count=39, rn=4),
#  Row(ownerId=163390848, likerId=175752496, count=37, rn=5),
#  Row(ownerId=163390848, likerId=159601100, count=33, rn=6),
#  Row(ownerId=163390848, likerId=167607484, count=33, rn=7),
#  Row(ownerId=163390848, likerId=82273960, count=32, rn=8),
#  Row(ownerId=163390848, likerId=196051230, count=31, rn=9),
#  Row(ownerId=163390848, likerId=310803048, count=31, rn=10),
#  Row(ownerId=176103654, likerId=4491295, count=10, rn=1),
#  Row(ownerId=176103654, likerId=30766089, count=7, rn=2),
#  Row(ownerId=176103654, likerId=137727045, count=7, rn=3),
#  Row(ownerId=176103654, likerId=134392535, count=6, rn=4),
#  Row(ownerId=176103654, likerId=176103654, count=6, rn=5),
#  Row(ownerId=176103654, likerId=231465913, count=6, rn=6),
#  Row(ownerId=176103654, likerId=152399597, count=5, rn=7),
#  Row(ownerId=176103654, likerId=921014, count=4, rn=8),
#  Row(ownerId=176103654, likerId=1250866, count=4, rn=9),
#  Row(ownerId=176103654, likerId=101871699, count=4, rn=10),
#  Row(ownerId=182703092, likerId=65079600, count=51, rn=1),
#  Row(ownerId=182703092, likerId=167177775, count=46, rn=2),
#  Row(ownerId=182703092, likerId=109767705, count=45, rn=3),
#  Row(ownerId=182703092, likerId=173498404, count=36, rn=4),
#  Row(ownerId=182703092, likerId=221628918, count=35, rn=5),
#  Row(ownerId=182703092, likerId=234540890, count=35, rn=6),
#  Row(ownerId=182703092, likerId=121702873, count=34, rn=7),
#  Row(ownerId=182703092, likerId=89139697, count=32, rn=8),
#  Row(ownerId=182703092, likerId=94312428, count=30, rn=9),
#  Row(ownerId=182703092, likerId=166770057, count=25, rn=10),
#  Row(ownerId=188409022, likerId=3000473, count=2, rn=1),
#  Row(ownerId=188409022, likerId=4729710, count=2, rn=2),
#  Row(ownerId=188409022, likerId=8309162, count=2, rn=3),
#  Row(ownerId=188409022, likerId=13043647, count=2, rn=4),
#  Row(ownerId=188409022, likerId=17336191, count=2, rn=5),
#  Row(ownerId=188409022, likerId=20104279, count=2, rn=6),
#  Row(ownerId=188409022, likerId=21064242, count=2, rn=7),
#  Row(ownerId=188409022, likerId=21406795, count=2, rn=8),
#  Row(ownerId=188409022, likerId=35782850, count=2, rn=9),
#  Row(ownerId=188409022, likerId=40932703, count=2, rn=10),
#  Row(ownerId=191743619, likerId=52649510, count=1, rn=1),
#  Row(ownerId=191743619, likerId=64609101, count=1, rn=2),
#  Row(ownerId=191743619, likerId=134714793, count=1, rn=3),
#  Row(ownerId=191743619, likerId=135781516, count=1, rn=4),
#  Row(ownerId=191743619, likerId=135897834, count=1, rn=5),
#  Row(ownerId=191743619, likerId=136202414, count=1, rn=6),
#  Row(ownerId=191743619, likerId=141957588, count=1, rn=7),
#  Row(ownerId=191743619, likerId=163637091, count=1, rn=8),
#  Row(ownerId=191743619, likerId=163899422, count=1, rn=9),
#  Row(ownerId=191743619, likerId=166111881, count=1, rn=10),
#  Row(ownerId=217400123, likerId=7515407, count=30, rn=1),
#  Row(ownerId=217400123, likerId=204850819, count=29, rn=2),
#  Row(ownerId=217400123, likerId=231121885, count=26, rn=3),
#  Row(ownerId=217400123, likerId=139988789, count=24, rn=4),
#  Row(ownerId=217400123, likerId=228377589, count=24, rn=5),
#  Row(ownerId=217400123, likerId=274571304, count=22, rn=6),
#  Row(ownerId=217400123, likerId=6365320, count=20, rn=7),
#  Row(ownerId=217400123, likerId=242771605, count=20, rn=8),
#  Row(ownerId=217400123, likerId=3350481, count=19, rn=9),
#  Row(ownerId=217400123, likerId=186643307, count=18, rn=10),
#  Row(ownerId=221352696, likerId=248820385, count=46, rn=1),
#  Row(ownerId=221352696, likerId=182481226, count=5, rn=2),
#  Row(ownerId=221352696, likerId=38151398, count=4, rn=3),
#  Row(ownerId=221352696, likerId=331599797, count=4, rn=4),
#  Row(ownerId=221352696, likerId=2952906, count=3, rn=5),
#  Row(ownerId=221352696, likerId=436004285, count=3, rn=6),
#  Row(ownerId=221352696, likerId=17762577, count=2, rn=7),
#  Row(ownerId=221352696, likerId=285128003, count=2, rn=8),
#  Row(ownerId=221352696, likerId=521324332, count=2, rn=9),
#  Row(ownerId=221352696, likerId=68268, count=1, rn=10),
#  Row(ownerId=226662314, likerId=104526887, count=1, rn=1),
#  Row(ownerId=228316485, likerId=358526644, count=3, rn=1),
#  Row(ownerId=228316485, likerId=222761898, count=2, rn=2),
#  Row(ownerId=228316485, likerId=224887518, count=2, rn=3),
#  Row(ownerId=228316485, likerId=253385345, count=2, rn=4),
#  Row(ownerId=228316485, likerId=445998540, count=2, rn=5),
#  Row(ownerId=228316485, likerId=449120233, count=2, rn=6),
#  Row(ownerId=228316485, likerId=452594447, count=2, rn=7),
#  Row(ownerId=228316485, likerId=531499730, count=2, rn=8),
#  Row(ownerId=228316485, likerId=533575617, count=2, rn=9),
#  Row(ownerId=228316485, likerId=134338766, count=1, rn=10),
#  Row(ownerId=238472934, likerId=993094, count=2, rn=1),
#  Row(ownerId=238472934, likerId=1997295, count=2, rn=2),
#  Row(ownerId=238472934, likerId=20533346, count=2, rn=3),
#  Row(ownerId=238472934, likerId=43268180, count=2, rn=4),
#  Row(ownerId=238472934, likerId=51634644, count=2, rn=5),
#  Row(ownerId=238472934, likerId=51728135, count=2, rn=6),
#  Row(ownerId=238472934, likerId=66717009, count=2, rn=7),
#  Row(ownerId=238472934, likerId=71347286, count=2, rn=8),
#  Row(ownerId=238472934, likerId=78833506, count=2, rn=9),
#  Row(ownerId=238472934, likerId=81552651, count=2, rn=10),
#  Row(ownerId=240137155, likerId=297834423, count=255, rn=1),
#  Row(ownerId=240137155, likerId=12530964, count=186, rn=2),
#  Row(ownerId=240137155, likerId=81059, count=182, rn=3),
#  Row(ownerId=240137155, likerId=341115574, count=165, rn=4),
#  Row(ownerId=240137155, likerId=417807563, count=138, rn=5),
#  Row(ownerId=240137155, likerId=200611622, count=112, rn=6),
#  Row(ownerId=240137155, likerId=362624575, count=107, rn=7),
#  Row(ownerId=240137155, likerId=290961043, count=105, rn=8),
#  Row(ownerId=240137155, likerId=422774981, count=91, rn=9),
#  Row(ownerId=240137155, likerId=364638600, count=86, rn=10),
#  Row(ownerId=258348451, likerId=258348451, count=173, rn=1),
#  Row(ownerId=258348451, likerId=488105116, count=141, rn=2),
#  Row(ownerId=258348451, likerId=505277076, count=96, rn=3),
#  Row(ownerId=258348451, likerId=241327047, count=84, rn=4),
#  Row(ownerId=258348451, likerId=472974206, count=30, rn=5),
#  Row(ownerId=258348451, likerId=473238377, count=25, rn=6),
#  Row(ownerId=258348451, likerId=469801773, count=19, rn=7),
#  Row(ownerId=258348451, likerId=505543298, count=15, rn=8),
#  Row(ownerId=258348451, likerId=517960597, count=14, rn=9),
#  Row(ownerId=258348451, likerId=535582286, count=14, rn=10),
#  Row(ownerId=271520742, likerId=147939041, count=2, rn=1),
#  Row(ownerId=271520742, likerId=160556821, count=2, rn=2),
#  Row(ownerId=271520742, likerId=239938322, count=2, rn=3),
#  Row(ownerId=271520742, likerId=262158981, count=2, rn=4),
#  Row(ownerId=271520742, likerId=271917446, count=2, rn=5),
#  Row(ownerId=271520742, likerId=384150370, count=2, rn=6),
#  Row(ownerId=271520742, likerId=497755630, count=2, rn=7),
#  Row(ownerId=271520742, likerId=540713507, count=2, rn=8),
#  Row(ownerId=271520742, likerId=77321174, count=1, rn=9),
#  Row(ownerId=271520742, likerId=190644114, count=1, rn=10),
#  Row(ownerId=272076217, likerId=209077977, count=40, rn=1),
#  Row(ownerId=272076217, likerId=187773040, count=10, rn=2),
#  Row(ownerId=272076217, likerId=237349576, count=9, rn=3),
#  Row(ownerId=272076217, likerId=157650866, count=8, rn=4),
#  Row(ownerId=272076217, likerId=14271367, count=7, rn=5),
#  Row(ownerId=272076217, likerId=239818444, count=7, rn=6),
#  Row(ownerId=272076217, likerId=56656912, count=6, rn=7),
#  Row(ownerId=272076217, likerId=235712272, count=6, rn=8),
#  Row(ownerId=272076217, likerId=299624068, count=6, rn=9),
#  Row(ownerId=272076217, likerId=330940300, count=6, rn=10),
#  Row(ownerId=304070865, likerId=310040500, count=1, rn=1),
#  Row(ownerId=305264077, likerId=444287982, count=4, rn=1),
#  Row(ownerId=305264077, likerId=73018560, count=3, rn=2),
#  Row(ownerId=305264077, likerId=100653089, count=3, rn=3),
#  Row(ownerId=305264077, likerId=140259235, count=3, rn=4),
#  Row(ownerId=305264077, likerId=294235573, count=3, rn=5),
#  Row(ownerId=305264077, likerId=98604087, count=2, rn=6),
#  Row(ownerId=305264077, likerId=158852170, count=2, rn=7),
#  Row(ownerId=305264077, likerId=501048241, count=2, rn=8),
#  Row(ownerId=305264077, likerId=15718985, count=1, rn=9),
#  Row(ownerId=305264077, likerId=63264332, count=1, rn=10),
#  Row(ownerId=323182907, likerId=137588004, count=43, rn=1),
#  Row(ownerId=323182907, likerId=323182907, count=33, rn=2),
#  Row(ownerId=323182907, likerId=157569281, count=4, rn=3),
#  Row(ownerId=323182907, likerId=474932788, count=3, rn=4),
#  Row(ownerId=323182907, likerId=31561987, count=2, rn=5),
#  Row(ownerId=323182907, likerId=103466590, count=2, rn=6),
#  Row(ownerId=323182907, likerId=133895975, count=2, rn=7),
#  Row(ownerId=323182907, likerId=195783233, count=2, rn=8),
#  Row(ownerId=323182907, likerId=220728284, count=2, rn=9),
#  Row(ownerId=323182907, likerId=251078409, count=2, rn=10),
#  Row(ownerId=343007631, likerId=225083289, count=6, rn=1),
#  Row(ownerId=343007631, likerId=451339231, count=5, rn=2),
#  Row(ownerId=343007631, likerId=331068083, count=4, rn=3),
#  Row(ownerId=343007631, likerId=371166306, count=4, rn=4),
#  Row(ownerId=343007631, likerId=373018625, count=4, rn=5),
#  Row(ownerId=343007631, likerId=384662458, count=4, rn=6),
#  Row(ownerId=343007631, likerId=478641559, count=4, rn=7),
#  Row(ownerId=343007631, likerId=517548686, count=4, rn=8),
#  Row(ownerId=343007631, likerId=546994719, count=4, rn=9),
#  Row(ownerId=343007631, likerId=403958758, count=3, rn=10),
#  Row(ownerId=424552330, likerId=1606701, count=1, rn=1),
#  Row(ownerId=424552330, likerId=236866202, count=1, rn=2),
#  Row(ownerId=424552330, likerId=238002110, count=1, rn=3),
#  Row(ownerId=424552330, likerId=272895754, count=1, rn=4),
#  Row(ownerId=424552330, likerId=293902876, count=1, rn=5),
#  Row(ownerId=424552330, likerId=550218374, count=1, rn=6),
#  Row(ownerId=467467040, likerId=167531770, count=3, rn=1),
#  Row(ownerId=467467040, likerId=166787262, count=1, rn=2),
#  Row(ownerId=467467040, likerId=182198818, count=1, rn=3),
#  Row(ownerId=467467040, likerId=231312873, count=1, rn=4),
#  Row(ownerId=467467040, likerId=488757804, count=1, rn=5),
#  Row(ownerId=467467040, likerId=534301458, count=1, rn=6),
#  Row(ownerId=467467040, likerId=547458177, count=1, rn=7),
#  Row(ownerId=467467040, likerId=552336803, count=1, rn=8),
#  Row(ownerId=467467040, likerId=553766733, count=1, rn=9),
#  Row(ownerId=467467040, likerId=561254833, count=1, rn=10),
#  Row(ownerId=556585982, likerId=2139934, count=4, rn=1),
#  Row(ownerId=556585982, likerId=505242875, count=3, rn=2),
#  Row(ownerId=556585982, likerId=316373930, count=2, rn=3),
#  Row(ownerId=556585982, likerId=43461016, count=1, rn=4),
#  Row(ownerId=556585982, likerId=287253779, count=1, rn=5),
#  Row(ownerId=556585982, likerId=306672643, count=1, rn=6),
#  Row(ownerId=556585982, likerId=322195570, count=1, rn=7),
#  Row(ownerId=556585982, likerId=330820703, count=1, rn=8),
#  Row(ownerId=556585982, likerId=410819883, count=1, rn=9),
#  Row(ownerId=556585982, likerId=449113312, count=1, rn=10),
#  Row(ownerId=1127, likerId=246350941, count=31, rn=1),
#  Row(ownerId=1127, likerId=1127, count=24, rn=2),
#  Row(ownerId=1127, likerId=12464664, count=19, rn=3),
#  Row(ownerId=1127, likerId=91290511, count=19, rn=4),
#  Row(ownerId=1127, likerId=2790271, count=12, rn=5),
#  Row(ownerId=1127, likerId=238020577, count=10, rn=6),
#  Row(ownerId=1127, likerId=558236910, count=10, rn=7),
#  Row(ownerId=1127, likerId=44237906, count=9, rn=8),
#  Row(ownerId=1127, likerId=134574091, count=9, rn=9),
#  Row(ownerId=1127, likerId=2002376, count=8, rn=10),
#  Row(ownerId=87982, likerId=772297, count=4, rn=1),
#  Row(ownerId=87982, likerId=171700, count=1, rn=2),
#  Row(ownerId=87982, likerId=284383, count=1, rn=3),
#  Row(ownerId=87982, likerId=408744, count=1, rn=4),
#  Row(ownerId=87982, likerId=412276, count=1, rn=5),
#  Row(ownerId=87982, likerId=2927370, count=1, rn=6),
#  Row(ownerId=87982, likerId=27997391, count=1, rn=7),
#  Row(ownerId=87982, likerId=39601520, count=1, rn=8),
#  Row(ownerId=87982, likerId=65091419, count=1, rn=9),
#  Row(ownerId=87982, likerId=208357220, count=1, rn=10),
#  Row(ownerId=2393612, likerId=2393612, count=6, rn=1),
#  Row(ownerId=2393612, likerId=10459798, count=3, rn=2),
#  Row(ownerId=2393612, likerId=84173876, count=3, rn=3),
#  Row(ownerId=2393612, likerId=445380182, count=3, rn=4),
#  Row(ownerId=2393612, likerId=2880469, count=2, rn=5),
#  Row(ownerId=2393612, likerId=10275341, count=2, rn=6),
#  Row(ownerId=2393612, likerId=16376037, count=2, rn=7),
#  Row(ownerId=2393612, likerId=52840162, count=2, rn=8),
#  Row(ownerId=2393612, likerId=513290215, count=2, rn=9),
#  Row(ownerId=2393612, likerId=527705256, count=2, rn=10),
#  Row(ownerId=2543221, likerId=178960845, count=6, rn=1),
#  Row(ownerId=2543221, likerId=36062275, count=4, rn=2),
#  Row(ownerId=2543221, likerId=182646256, count=4, rn=3),
#  Row(ownerId=2543221, likerId=1985084, count=3, rn=4),
#  Row(ownerId=2543221, likerId=9607693, count=3, rn=5),
#  Row(ownerId=2543221, likerId=10812706, count=3, rn=6),
#  Row(ownerId=2543221, likerId=12946597, count=3, rn=7),
#  Row(ownerId=2543221, likerId=48026474, count=3, rn=8),
#  Row(ownerId=2543221, likerId=77037702, count=3, rn=9),
#  Row(ownerId=2543221, likerId=79947626, count=3, rn=10),
#  Row(ownerId=3447635, likerId=589303, count=3, rn=1),
#  Row(ownerId=3447635, likerId=327415351, count=3, rn=2),
#  Row(ownerId=3447635, likerId=970144, count=2, rn=3),
#  Row(ownerId=3447635, likerId=2291047, count=2, rn=4),
#  Row(ownerId=3447635, likerId=2961695, count=2, rn=5),
#  Row(ownerId=3447635, likerId=3464239, count=2, rn=6),
#  Row(ownerId=3447635, likerId=10611322, count=2, rn=7),
#  Row(ownerId=3447635, likerId=17819554, count=2, rn=8),
#  Row(ownerId=3447635, likerId=157017794, count=2, rn=9),
#  Row(ownerId=3447635, likerId=82402, count=1, rn=10),
#  Row(ownerId=3670245, likerId=25004044, count=216, rn=1),
#  Row(ownerId=3670245, likerId=171162670, count=50, rn=2),
#  Row(ownerId=3670245, likerId=63869733, count=39, rn=3),
#  Row(ownerId=3670245, likerId=27894623, count=38, rn=4),
#  Row(ownerId=3670245, likerId=2326183, count=37, rn=5),
#  Row(ownerId=3670245, likerId=216045553, count=37, rn=6),
#  Row(ownerId=3670245, likerId=310859831, count=36, rn=7),
#  Row(ownerId=3670245, likerId=23013717, count=31, rn=8),
#  Row(ownerId=3670245, likerId=3406636, count=28, rn=9),
#  Row(ownerId=3670245, likerId=160489244, count=24, rn=10),
#  Row(ownerId=4428906, likerId=22678, count=2, rn=1),
#  Row(ownerId=4428906, likerId=93528, count=2, rn=2),
#  Row(ownerId=4428906, likerId=726021, count=2, rn=3),
#  Row(ownerId=4428906, likerId=2033396, count=2, rn=4),
#  Row(ownerId=4428906, likerId=3494224, count=2, rn=5),
#  Row(ownerId=4428906, likerId=7196581, count=2, rn=6),
#  Row(ownerId=4428906, likerId=12022170, count=2, rn=7),
#  Row(ownerId=4428906, likerId=15565164, count=2, rn=8),
#  Row(ownerId=4428906, likerId=15944048, count=2, rn=9),
#  Row(ownerId=4428906, likerId=38157755, count=2, rn=10),
#  Row(ownerId=4556965, likerId=39629801, count=8, rn=1),
#  Row(ownerId=4556965, likerId=3953179, count=7, rn=2),
#  Row(ownerId=4556965, likerId=2325035, count=6, rn=3),
#  Row(ownerId=4556965, likerId=320754, count=5, rn=4),
#  Row(ownerId=4556965, likerId=14231839, count=5, rn=5),
#  Row(ownerId=4556965, likerId=23174568, count=5, rn=6),
#  Row(ownerId=4556965, likerId=5379160, count=4, rn=7),
#  Row(ownerId=4556965, likerId=16796643, count=4, rn=8),
#  Row(ownerId=4556965, likerId=17063052, count=4, rn=9),
#  Row(ownerId=4556965, likerId=28643283, count=4, rn=10),
#  Row(ownerId=6054464, likerId=7837989, count=1, rn=1),
#  Row(ownerId=6054464, likerId=57156238, count=1, rn=2),
#  Row(ownerId=6054464, likerId=83483858, count=1, rn=3),
#  Row(ownerId=6054464, likerId=101822925, count=1, rn=4),
#  Row(ownerId=6921930, likerId=1441661, count=6, rn=1),
#  Row(ownerId=6921930, likerId=20381, count=4, rn=2),
#  Row(ownerId=6921930, likerId=367202, count=3, rn=3),
#  Row(ownerId=6921930, likerId=208284, count=2, rn=4),
#  Row(ownerId=6921930, likerId=480313, count=2, rn=5),
#  Row(ownerId=6921930, likerId=668313, count=2, rn=6),
#  Row(ownerId=6921930, likerId=1229658, count=2, rn=7),
#  Row(ownerId=6921930, likerId=5427075, count=2, rn=8),
#  Row(ownerId=6921930, likerId=22736817, count=2, rn=9),
#  Row(ownerId=6921930, likerId=24237242, count=2, rn=10),
#  Row(ownerId=7837989, likerId=3407732, count=2, rn=1),
#  Row(ownerId=7837989, likerId=11463515, count=2, rn=2),
#  Row(ownerId=7837989, likerId=16760894, count=2, rn=3),
#  Row(ownerId=7837989, likerId=22496431, count=2, rn=4),
#  Row(ownerId=7837989, likerId=22579567, count=2, rn=5),
#  Row(ownerId=7837989, likerId=23686413, count=2, rn=6),
#  Row(ownerId=7837989, likerId=37209871, count=2, rn=7),
#  Row(ownerId=7837989, likerId=80216783, count=2, rn=8),
#  Row(ownerId=7837989, likerId=80680458, count=2, rn=9),
#  Row(ownerId=7837989, likerId=119438313, count=2, rn=10),
#  Row(ownerId=9370920, likerId=76782, count=1, rn=1),
#  Row(ownerId=9370920, likerId=4162336, count=1, rn=2),
#  Row(ownerId=9370920, likerId=11554671, count=1, rn=3),
#  Row(ownerId=9370920, likerId=20137333, count=1, rn=4),
#  Row(ownerId=9370920, likerId=23430275, count=1, rn=5),
#  Row(ownerId=9370920, likerId=24967609, count=1, rn=6),
#  Row(ownerId=9370920, likerId=26159411, count=1, rn=7),
#  Row(ownerId=9370920, likerId=26824714, count=1, rn=8),
#  Row(ownerId=9370920, likerId=31059841, count=1, rn=9),
#  Row(ownerId=9370920, likerId=37122628, count=1, rn=10),
#  Row(ownerId=9697916, likerId=11159192, count=32, rn=1),
#  Row(ownerId=9697916, likerId=261290628, count=12, rn=2),
#  Row(ownerId=9697916, likerId=155372318, count=10, rn=3),
#  Row(ownerId=9697916, likerId=130883582, count=9, rn=4),
#  Row(ownerId=9697916, likerId=171935137, count=9, rn=5),
#  Row(ownerId=9697916, likerId=504926442, count=9, rn=6),
#  Row(ownerId=9697916, likerId=85027674, count=8, rn=7),
#  Row(ownerId=9697916, likerId=7939100, count=6, rn=8),
#  Row(ownerId=9697916, likerId=355518296, count=6, rn=9),
#  Row(ownerId=9697916, likerId=6163304, count=5, rn=10),
#  Row(ownerId=11092880, likerId=96652666, count=2, rn=1),
#  Row(ownerId=11092880, likerId=350920, count=1, rn=2),
#  Row(ownerId=11092880, likerId=1098272, count=1, rn=3),
#  Row(ownerId=11092880, likerId=1530820, count=1, rn=4),
#  Row(ownerId=11092880, likerId=6105582, count=1, rn=5),
#  Row(ownerId=11092880, likerId=46117406, count=1, rn=6),
#  Row(ownerId=11092880, likerId=463667696, count=1, rn=7),
#  Row(ownerId=11092880, likerId=537507438, count=1, rn=8),
#  Row(ownerId=12045806, likerId=12045806, count=2, rn=1),
#  Row(ownerId=12045806, likerId=415390316, count=1, rn=2),
#  Row(ownerId=12045806, likerId=476988423, count=1, rn=3),
#  Row(ownerId=17934739, likerId=168004, count=1, rn=1),
#  Row(ownerId=17934739, likerId=8317861, count=1, rn=2),
#  Row(ownerId=17934739, likerId=30067410, count=1, rn=3),
#  Row(ownerId=17934739, likerId=164672033, count=1, rn=4),
#  Row(ownerId=17934739, likerId=202598902, count=1, rn=5),
#  Row(ownerId=17934739, likerId=233641483, count=1, rn=6),
#  Row(ownerId=17934739, likerId=363534917, count=1, rn=7),
#  Row(ownerId=17934739, likerId=382022575, count=1, rn=8),
#  Row(ownerId=17934739, likerId=430307532, count=1, rn=9),
#  Row(ownerId=19294181, likerId=90191989, count=17, rn=1),
#  Row(ownerId=19294181, likerId=29381780, count=15, rn=2),
#  Row(ownerId=19294181, likerId=89641782, count=15, rn=3),
#  Row(ownerId=19294181, likerId=29015129, count=13, rn=4),
#  Row(ownerId=19294181, likerId=119708107, count=13, rn=5),
#  Row(ownerId=19294181, likerId=252575964, count=13, rn=6),
#  Row(ownerId=19294181, likerId=18309255, count=8, rn=7),
#  Row(ownerId=19294181, likerId=366327166, count=6, rn=8),
#  Row(ownerId=19294181, likerId=19933555, count=5, rn=9),
#  Row(ownerId=19294181, likerId=41738689, count=5, rn=10),
#  Row(ownerId=20020650, likerId=362641034, count=2, rn=1),
#  Row(ownerId=20020650, likerId=227174646, count=1, rn=2),
#  Row(ownerId=20020650, likerId=305856845, count=1, rn=3),
#  Row(ownerId=25863735, likerId=163405258, count=69, rn=1),
#  Row(ownerId=25863735, likerId=242494477, count=22, rn=2),
#  Row(ownerId=25863735, likerId=16201969, count=18, rn=3),
#  Row(ownerId=25863735, likerId=618002, count=7, rn=4),
#  Row(ownerId=25863735, likerId=178703306, count=4, rn=5),
#  Row(ownerId=25863735, likerId=12319063, count=3, rn=6),
#  Row(ownerId=25863735, likerId=13091512, count=3, rn=7),
#  Row(ownerId=25863735, likerId=135249331, count=3, rn=8),
#  Row(ownerId=25863735, likerId=572560, count=2, rn=9),
#  Row(ownerId=25863735, likerId=7640331, count=2, rn=10),
#  Row(ownerId=27699073, likerId=144548561, count=1, rn=1),
#  Row(ownerId=27699073, likerId=193281863, count=1, rn=2),
#  Row(ownerId=27699073, likerId=252495692, count=1, rn=3),
#  Row(ownerId=27699073, likerId=338951618, count=1, rn=4),
#  Row(ownerId=27699073, likerId=342630969, count=1, rn=5),
#  Row(ownerId=27699073, likerId=370123959, count=1, rn=6),
#  Row(ownerId=27699073, likerId=376971088, count=1, rn=7),
#  Row(ownerId=27699073, likerId=471652140, count=1, rn=8),
#  Row(ownerId=32297252, likerId=803830, count=1, rn=1),
#  Row(ownerId=32297252, likerId=1681976, count=1, rn=2),
#  Row(ownerId=32297252, likerId=8017844, count=1, rn=3),
#  Row(ownerId=32297252, likerId=8671566, count=1, rn=4),
#  Row(ownerId=32297252, likerId=25475641, count=1, rn=5),
#  Row(ownerId=32297252, likerId=66383172, count=1, rn=6),
#  Row(ownerId=32297252, likerId=199456066, count=1, rn=7),
#  Row(ownerId=32297252, likerId=422628771, count=1, rn=8),
#  Row(ownerId=35640930, likerId=342343346, count=3, rn=1),
#  Row(ownerId=35640930, likerId=42067269, count=2, rn=2),
#  Row(ownerId=35640930, likerId=63809007, count=2, rn=3),
#  Row(ownerId=35640930, likerId=64181903, count=2, rn=4),
#  Row(ownerId=35640930, likerId=138336505, count=2, rn=5),
#  Row(ownerId=35640930, likerId=152069839, count=2, rn=6),
#  Row(ownerId=35640930, likerId=165792771, count=2, rn=7),
#  Row(ownerId=35640930, likerId=243305279, count=2, rn=8),
#  Row(ownerId=35640930, likerId=733271, count=1, rn=9),
#  Row(ownerId=35640930, likerId=968815, count=1, rn=10),
#  Row(ownerId=37046996, likerId=45525736, count=2, rn=1),
#  Row(ownerId=37046996, likerId=68879537, count=2, rn=2),
#  Row(ownerId=37046996, likerId=122466811, count=2, rn=3),
#  Row(ownerId=37046996, likerId=139664761, count=2, rn=4),
#  Row(ownerId=37046996, likerId=141155661, count=2, rn=5),
#  Row(ownerId=37046996, likerId=157081430, count=2, rn=6),
#  Row(ownerId=37046996, likerId=246799871, count=2, rn=7),
#  Row(ownerId=37046996, likerId=247852841, count=2, rn=8),
#  Row(ownerId=37046996, likerId=345879453, count=2, rn=9),
#  Row(ownerId=37046996, likerId=10530510, count=1, rn=10),
#  Row(ownerId=44208335, likerId=44208335, count=8, rn=1),
#  Row(ownerId=44208335, likerId=294836787, count=8, rn=2),
#  Row(ownerId=44208335, likerId=328601618, count=8, rn=3),
#  Row(ownerId=44208335, likerId=5119525, count=7, rn=4),
#  Row(ownerId=44208335, likerId=126201148, count=7, rn=5),
#  Row(ownerId=44208335, likerId=208886744, count=7, rn=6),
#  Row(ownerId=44208335, likerId=420498572, count=7, rn=7),
#  Row(ownerId=44208335, likerId=79695883, count=6, rn=8),
#  Row(ownerId=44208335, likerId=274564616, count=6, rn=9),
#  Row(ownerId=44208335, likerId=282139605, count=6, rn=10),
#  Row(ownerId=44395726, likerId=44395726, count=1, rn=1),
#  Row(ownerId=44395726, likerId=92206688, count=1, rn=2),
#  Row(ownerId=44395726, likerId=162550142, count=1, rn=3),
#  Row(ownerId=46025049, likerId=312102223, count=3, rn=1),
#  Row(ownerId=46025049, likerId=54223471, count=2, rn=2),
#  Row(ownerId=46025049, likerId=360219755, count=2, rn=3),
#  Row(ownerId=46025049, likerId=31782084, count=1, rn=4),
#  Row(ownerId=46025049, likerId=55420516, count=1, rn=5),
#  Row(ownerId=46025049, likerId=97837216, count=1, rn=6),
#  Row(ownerId=46025049, likerId=147273591, count=1, rn=7),
#  Row(ownerId=46025049, likerId=296366237, count=1, rn=8),
#  Row(ownerId=46025049, likerId=331102822, count=1, rn=9),
#  Row(ownerId=46025049, likerId=342136153, count=1, rn=10),
#  Row(ownerId=51333272, likerId=372420, count=5, rn=1),
#  Row(ownerId=51333272, likerId=24236574, count=3, rn=2),
#  Row(ownerId=51333272, likerId=52308069, count=3, rn=3),
#  Row(ownerId=51333272, likerId=73206180, count=3, rn=4),
#  Row(ownerId=51333272, likerId=98989485, count=3, rn=5),
#  Row(ownerId=51333272, likerId=10016467, count=2, rn=6),
#  Row(ownerId=51333272, likerId=16244615, count=2, rn=7),
#  Row(ownerId=51333272, likerId=29619324, count=2, rn=8),
#  Row(ownerId=51333272, likerId=50675391, count=2, rn=9),
#  Row(ownerId=51333272, likerId=62401277, count=2, rn=10),
#  Row(ownerId=52055078, likerId=25136, count=1, rn=1),
#  Row(ownerId=52055078, likerId=104174, count=1, rn=2),
#  Row(ownerId=52055078, likerId=135450, count=1, rn=3),
#  Row(ownerId=52055078, likerId=146734, count=1, rn=4),
#  Row(ownerId=52055078, likerId=323749, count=1, rn=5),
#  Row(ownerId=52055078, likerId=532484, count=1, rn=6),
#  Row(ownerId=52055078, likerId=771805, count=1, rn=7),
#  Row(ownerId=52055078, likerId=3014383, count=1, rn=8),
#  Row(ownerId=52055078, likerId=3384842, count=1, rn=9),
#  Row(ownerId=52055078, likerId=4497650, count=1, rn=10),
#  Row(ownerId=56706631, likerId=327284340, count=2, rn=1),
#  Row(ownerId=56706631, likerId=823407, count=1, rn=2),
#  Row(ownerId=56706631, likerId=2945616, count=1, rn=3),
#  Row(ownerId=56706631, likerId=32507182, count=1, rn=4),
#  Row(ownerId=56706631, likerId=35331829, count=1, rn=5),
#  Row(ownerId=56706631, likerId=40201922, count=1, rn=6),
#  Row(ownerId=56706631, likerId=44168872, count=1, rn=7),
#  Row(ownerId=56706631, likerId=49894967, count=1, rn=8),
#  Row(ownerId=56706631, likerId=66280259, count=1, rn=9),
#  Row(ownerId=56706631, likerId=68046803, count=1, rn=10),
#  Row(ownerId=61421247, likerId=162021432, count=6, rn=1),
#  Row(ownerId=61421247, likerId=375502628, count=5, rn=2),
#  Row(ownerId=61421247, likerId=20640508, count=4, rn=3),
#  Row(ownerId=61421247, likerId=116500619, count=4, rn=4),
#  Row(ownerId=61421247, likerId=182110855, count=4, rn=5),
#  Row(ownerId=61421247, likerId=258600349, count=4, rn=6),
#  Row(ownerId=61421247, likerId=22804401, count=3, rn=7),
#  Row(ownerId=61421247, likerId=27969702, count=3, rn=8),
#  Row(ownerId=61421247, likerId=35611202, count=3, rn=9),
#  Row(ownerId=61421247, likerId=68027639, count=3, rn=10),
#  Row(ownerId=67523103, likerId=480475585, count=130, rn=1),
#  Row(ownerId=67523103, likerId=355150926, count=21, rn=2),
#  Row(ownerId=67523103, likerId=423540525, count=18, rn=3),
#  Row(ownerId=67523103, likerId=376334251, count=15, rn=4),
#  Row(ownerId=67523103, likerId=35600214, count=6, rn=5),
#  Row(ownerId=67523103, likerId=429786989, count=4, rn=6),
#  Row(ownerId=67523103, likerId=259323209, count=3, rn=7),
#  Row(ownerId=67523103, likerId=544781277, count=3, rn=8),
#  Row(ownerId=67523103, likerId=10075203, count=2, rn=9),
#  Row(ownerId=67523103, likerId=538853855, count=2, rn=10),
#  Row(ownerId=75372497, likerId=294067677, count=2, rn=1),
#  Row(ownerId=75372497, likerId=528408155, count=2, rn=2),
#  Row(ownerId=75372497, likerId=86939503, count=1, rn=3),
#  Row(ownerId=75372497, likerId=134431341, count=1, rn=4),
#  Row(ownerId=75372497, likerId=161759429, count=1, rn=5),
#  Row(ownerId=75372497, likerId=169281255, count=1, rn=6),
#  Row(ownerId=75372497, likerId=173854784, count=1, rn=7),
#  Row(ownerId=75372497, likerId=190920570, count=1, rn=8),
#  Row(ownerId=75372497, likerId=234306031, count=1, rn=9),
#  Row(ownerId=75372497, likerId=303871797, count=1, rn=10),
#  Row(ownerId=78801943, likerId=501664419, count=5, rn=1),
#  Row(ownerId=78801943, likerId=67444325, count=2, rn=2),
#  Row(ownerId=78801943, likerId=233943237, count=2, rn=3),
#  Row(ownerId=78801943, likerId=14815175, count=1, rn=4),
#  Row(ownerId=78801943, likerId=60182185, count=1, rn=5),
#  Row(ownerId=78801943, likerId=263831366, count=1, rn=6),
#  Row(ownerId=78801943, likerId=302387128, count=1, rn=7),
#  Row(ownerId=78801943, likerId=325412659, count=1, rn=8),
#  Row(ownerId=78801943, likerId=408201603, count=1, rn=9),
#  Row(ownerId=78801943, likerId=435794196, count=1, rn=10),
#  Row(ownerId=88550831, likerId=2810190, count=3, rn=1),
#  Row(ownerId=88550831, likerId=26452030, count=3, rn=2),
#  Row(ownerId=88550831, likerId=51764671, count=3, rn=3),
#  Row(ownerId=88550831, likerId=104001294, count=3, rn=4),
#  Row(ownerId=88550831, likerId=110745175, count=3, rn=5),
#  Row(ownerId=88550831, likerId=132891357, count=3, rn=6),
#  Row(ownerId=88550831, likerId=133194130, count=3, rn=7),
#  Row(ownerId=88550831, likerId=133746807, count=3, rn=8),
#  Row(ownerId=88550831, likerId=142125384, count=3, rn=9),
#  Row(ownerId=88550831, likerId=146002326, count=3, rn=10),
#  Row(ownerId=89330681, likerId=460666999, count=37, rn=1),
#  Row(ownerId=89330681, likerId=301604655, count=36, rn=2),
#  Row(ownerId=89330681, likerId=457025449, count=36, rn=3),
#  Row(ownerId=89330681, likerId=517722914, count=36, rn=4),
#  Row(ownerId=89330681, likerId=356096702, count=34, rn=5),
#  Row(ownerId=89330681, likerId=338737906, count=32, rn=6),
#  Row(ownerId=89330681, likerId=565551560, count=31, rn=7),
#  Row(ownerId=89330681, likerId=288943711, count=30, rn=8),
#  Row(ownerId=89330681, likerId=383123833, count=30, rn=9),
#  Row(ownerId=89330681, likerId=517844427, count=29, rn=10),
#  Row(ownerId=97391600, likerId=478228685, count=8, rn=1),
#  Row(ownerId=97391600, likerId=24528661, count=7, rn=2),
#  Row(ownerId=97391600, likerId=143758912, count=7, rn=3),
#  Row(ownerId=97391600, likerId=184871854, count=6, rn=4),
#  Row(ownerId=97391600, likerId=445607938, count=6, rn=5),
#  Row(ownerId=97391600, likerId=98672471, count=5, rn=6),
#  Row(ownerId=97391600, likerId=41700258, count=4, rn=7),
#  Row(ownerId=97391600, likerId=42056139, count=4, rn=8),
#  Row(ownerId=97391600, likerId=54981912, count=4, rn=9),
#  Row(ownerId=97391600, likerId=61484161, count=4, rn=10),
#  Row(ownerId=136034317, likerId=136034317, count=15, rn=1),
#  Row(ownerId=136034317, likerId=7753639, count=9, rn=2),
#  Row(ownerId=136034317, likerId=47375596, count=1, rn=3),
#  Row(ownerId=136034317, likerId=170681756, count=1, rn=4),
#  Row(ownerId=136034317, likerId=280080770, count=1, rn=5),
#  Row(ownerId=136034317, likerId=417367954, count=1, rn=6),
#  Row(ownerId=136034317, likerId=483689499, count=1, rn=7),
#  Row(ownerId=143426197, likerId=314612222, count=7, rn=1),
#  Row(ownerId=143426197, likerId=108786161, count=5, rn=2),
#  Row(ownerId=143426197, likerId=168072962, count=5, rn=3),
#  Row(ownerId=143426197, likerId=185064001, count=5, rn=4),
#  Row(ownerId=143426197, likerId=316546837, count=5, rn=5),
#  Row(ownerId=143426197, likerId=6390922, count=3, rn=6),
#  Row(ownerId=143426197, likerId=108431008, count=3, rn=7),
#  Row(ownerId=143426197, likerId=334308091, count=3, rn=8),
#  Row(ownerId=143426197, likerId=378035968, count=3, rn=9),
#  Row(ownerId=143426197, likerId=483061502, count=3, rn=10),
#  Row(ownerId=150740926, likerId=26523539, count=1, rn=1),
#  Row(ownerId=150740926, likerId=54625039, count=1, rn=2),
#  Row(ownerId=150740926, likerId=89407375, count=1, rn=3),
#  Row(ownerId=150740926, likerId=125691034, count=1, rn=4),
#  Row(ownerId=150740926, likerId=131990424, count=1, rn=5),
#  Row(ownerId=150740926, likerId=133756797, count=1, rn=6),
#  Row(ownerId=150740926, likerId=150248086, count=1, rn=7),
#  Row(ownerId=150740926, likerId=159257898, count=1, rn=8),
#  Row(ownerId=150740926, likerId=160895735, count=1, rn=9),
#  Row(ownerId=150740926, likerId=161003728, count=1, rn=10),
#  Row(ownerId=151866057, likerId=150750654, count=2, rn=1),
#  Row(ownerId=151866057, likerId=28785081, count=1, rn=2),
#  Row(ownerId=151866057, likerId=50965827, count=1, rn=3),
#  Row(ownerId=151866057, likerId=93959121, count=1, rn=4),
#  Row(ownerId=151866057, likerId=102669960, count=1, rn=5),
#  Row(ownerId=151866057, likerId=117365881, count=1, rn=6),
#  Row(ownerId=151866057, likerId=119578420, count=1, rn=7),
#  Row(ownerId=151866057, likerId=159655325, count=1, rn=8),
#  Row(ownerId=151866057, likerId=173099591, count=1, rn=9),
#  Row(ownerId=151866057, likerId=207386847, count=1, rn=10),
#  Row(ownerId=154837189, likerId=440750566, count=2, rn=1),
#  Row(ownerId=154837189, likerId=70290907, count=1, rn=2),
#  Row(ownerId=154837189, likerId=131712491, count=1, rn=3),
#  Row(ownerId=156525684, likerId=52239164, count=3, rn=1),
#  Row(ownerId=156525684, likerId=89308313, count=3, rn=2),
#  Row(ownerId=156525684, likerId=146492388, count=3, rn=3),
#  Row(ownerId=156525684, likerId=201191849, count=3, rn=4),
#  Row(ownerId=156525684, likerId=6273502, count=2, rn=5),
#  Row(ownerId=156525684, likerId=66983617, count=2, rn=6),
#  Row(ownerId=156525684, likerId=87549644, count=2, rn=7),
#  Row(ownerId=156525684, likerId=100245467, count=2, rn=8),
#  Row(ownerId=156525684, likerId=103513216, count=2, rn=9),
#  Row(ownerId=156525684, likerId=128084495, count=2, rn=10),
#  Row(ownerId=158942374, likerId=133734955, count=22, rn=1),
#  Row(ownerId=158942374, likerId=134692483, count=21, rn=2),
#  Row(ownerId=158942374, likerId=196261033, count=21, rn=3),
#  Row(ownerId=158942374, likerId=154115089, count=20, rn=4),
#  Row(ownerId=158942374, likerId=170526244, count=20, rn=5),
#  Row(ownerId=158942374, likerId=10748193, count=17, rn=6),
#  Row(ownerId=158942374, likerId=31367373, count=17, rn=7),
#  Row(ownerId=158942374, likerId=494398132, count=17, rn=8),
#  Row(ownerId=158942374, likerId=559341, count=16, rn=9),
#  Row(ownerId=158942374, likerId=236768165, count=16, rn=10),
#  Row(ownerId=165399768, likerId=540685536, count=6, rn=1),
#  Row(ownerId=165399768, likerId=130461962, count=4, rn=2),
#  Row(ownerId=165399768, likerId=666749, count=3, rn=3),
#  Row(ownerId=165399768, likerId=25677543, count=3, rn=4),
#  Row(ownerId=165399768, likerId=29265662, count=3, rn=5),
#  Row(ownerId=165399768, likerId=39575615, count=3, rn=6),
#  Row(ownerId=165399768, likerId=67793212, count=3, rn=7),
#  Row(ownerId=165399768, likerId=81819465, count=3, rn=8),
#  Row(ownerId=165399768, likerId=135908933, count=3, rn=9),
#  Row(ownerId=165399768, likerId=145867610, count=3, rn=10),
#  Row(ownerId=167664432, likerId=85393825, count=4, rn=1),
#  Row(ownerId=167664432, likerId=501577805, count=4, rn=2),
#  Row(ownerId=167664432, likerId=13240750, count=3, rn=3),
#  Row(ownerId=167664432, likerId=36550200, count=3, rn=4),
#  Row(ownerId=167664432, likerId=280498899, count=3, rn=5),
#  Row(ownerId=167664432, likerId=444206965, count=3, rn=6),
#  Row(ownerId=167664432, likerId=7356923, count=2, rn=7),
#  Row(ownerId=167664432, likerId=217139042, count=2, rn=8),
#  Row(ownerId=167664432, likerId=220814538, count=2, rn=9),
#  Row(ownerId=167664432, likerId=1594612, count=1, rn=10),
#  Row(ownerId=174926957, likerId=174926957, count=71, rn=1),
#  Row(ownerId=174926957, likerId=183298930, count=27, rn=2),
#  Row(ownerId=174926957, likerId=6113303, count=25, rn=3),
#  Row(ownerId=174926957, likerId=9954986, count=23, rn=4),
#  Row(ownerId=174926957, likerId=329648429, count=21, rn=5),
#  Row(ownerId=174926957, likerId=382042826, count=20, rn=6),
#  Row(ownerId=174926957, likerId=155048200, count=18, rn=7),
#  Row(ownerId=174926957, likerId=418095561, count=18, rn=8),
#  Row(ownerId=174926957, likerId=167027930, count=16, rn=9),
#  Row(ownerId=174926957, likerId=377036222, count=16, rn=10),
#  Row(ownerId=191339513, likerId=5127464, count=1, rn=1),
#  Row(ownerId=191339513, likerId=121439768, count=1, rn=2),
#  Row(ownerId=191339513, likerId=128491011, count=1, rn=3),
#  Row(ownerId=191339513, likerId=142081461, count=1, rn=4),
#  Row(ownerId=191339513, likerId=146824186, count=1, rn=5),
#  Row(ownerId=191339513, likerId=147310022, count=1, rn=6),
#  Row(ownerId=191339513, likerId=147503855, count=1, rn=7),
#  Row(ownerId=191339513, likerId=152242214, count=1, rn=8),
#  Row(ownerId=191339513, likerId=155856945, count=1, rn=9),
#  Row(ownerId=191339513, likerId=164159955, count=1, rn=10),
#  Row(ownerId=198301335, likerId=220064320, count=2, rn=1),
#  Row(ownerId=198301335, likerId=15159930, count=1, rn=2),
#  Row(ownerId=198301335, likerId=38730018, count=1, rn=3),
#  Row(ownerId=198301335, likerId=60515609, count=1, rn=4),
#  Row(ownerId=198301335, likerId=72955449, count=1, rn=5),
#  Row(ownerId=198301335, likerId=107225934, count=1, rn=6),
#  Row(ownerId=198301335, likerId=157862361, count=1, rn=7),
#  Row(ownerId=198301335, likerId=173770798, count=1, rn=8),
#  Row(ownerId=198301335, likerId=193554491, count=1, rn=9),
#  Row(ownerId=198301335, likerId=209925271, count=1, rn=10),
#  Row(ownerId=230853332, likerId=271693590, count=81, rn=1),
#  Row(ownerId=230853332, likerId=230853332, count=75, rn=2),
#  Row(ownerId=230853332, likerId=274126970, count=27, rn=3),
#  Row(ownerId=230853332, likerId=155846028, count=23, rn=4),
#  Row(ownerId=230853332, likerId=176692157, count=23, rn=5),
#  Row(ownerId=230853332, likerId=370395645, count=18, rn=6),
#  Row(ownerId=230853332, likerId=334014881, count=16, rn=7),
#  Row(ownerId=230853332, likerId=16742243, count=14, rn=8),
#  Row(ownerId=230853332, likerId=313599252, count=12, rn=9),
#  Row(ownerId=230853332, likerId=69382750, count=11, rn=10),
#  Row(ownerId=239100632, likerId=160936649, count=6, rn=1),
#  Row(ownerId=239100632, likerId=204332210, count=6, rn=2),
#  Row(ownerId=239100632, likerId=236178303, count=6, rn=3),
#  Row(ownerId=239100632, likerId=316138177, count=6, rn=4),
#  Row(ownerId=239100632, likerId=415024664, count=6, rn=5),
#  Row(ownerId=239100632, likerId=449961210, count=6, rn=6),
#  Row(ownerId=239100632, likerId=4810747, count=5, rn=7),
#  Row(ownerId=239100632, likerId=187766875, count=5, rn=8),
#  Row(ownerId=239100632, likerId=392352179, count=5, rn=9),
#  Row(ownerId=239100632, likerId=441140495, count=5, rn=10),
#  Row(ownerId=240203653, likerId=18361143, count=5, rn=1),
#  Row(ownerId=240203653, likerId=5070475, count=4, rn=2),
#  Row(ownerId=240203653, likerId=6677855, count=4, rn=3),
#  Row(ownerId=240203653, likerId=41781605, count=4, rn=4),
#  Row(ownerId=240203653, likerId=64392783, count=4, rn=5),
#  Row(ownerId=240203653, likerId=78299420, count=4, rn=6),
#  Row(ownerId=240203653, likerId=203955903, count=4, rn=7),
#  Row(ownerId=240203653, likerId=1029119, count=3, rn=8),
#  Row(ownerId=240203653, likerId=1328133, count=3, rn=9),
#  Row(ownerId=240203653, likerId=5074713, count=3, rn=10),
#  Row(ownerId=254495929, likerId=253071343, count=9, rn=1),
#  Row(ownerId=254495929, likerId=310632968, count=3, rn=2),
#  Row(ownerId=254495929, likerId=322106236, count=3, rn=3),
#  Row(ownerId=254495929, likerId=544134314, count=3, rn=4),
#  Row(ownerId=254495929, likerId=137275337, count=2, rn=5),
#  Row(ownerId=254495929, likerId=177323134, count=2, rn=6),
#  Row(ownerId=254495929, likerId=190029529, count=2, rn=7),
#  Row(ownerId=254495929, likerId=493846697, count=2, rn=8),
#  Row(ownerId=254495929, likerId=4460944, count=1, rn=9),
#  Row(ownerId=254495929, likerId=18395432, count=1, rn=10),
#  Row(ownerId=258629887, likerId=75323639, count=2, rn=1),
#  Row(ownerId=258629887, likerId=408541377, count=2, rn=2),
#  Row(ownerId=258629887, likerId=502422801, count=2, rn=3),
#  Row(ownerId=258629887, likerId=6124345, count=1, rn=4),
#  Row(ownerId=258629887, likerId=20049326, count=1, rn=5),
#  Row(ownerId=258629887, likerId=50093861, count=1, rn=6),
#  Row(ownerId=258629887, likerId=165650550, count=1, rn=7),
#  Row(ownerId=258629887, likerId=204382636, count=1, rn=8),
#  Row(ownerId=258629887, likerId=263488654, count=1, rn=9),
#  Row(ownerId=258629887, likerId=294816783, count=1, rn=10),
#  Row(ownerId=266328305, likerId=266328305, count=3, rn=1),
#  Row(ownerId=266328305, likerId=258929214, count=2, rn=2),
#  Row(ownerId=266328305, likerId=296118928, count=2, rn=3),
#  Row(ownerId=266328305, likerId=154174327, count=1, rn=4),
#  Row(ownerId=266328305, likerId=173828056, count=1, rn=5),
#  Row(ownerId=266328305, likerId=199202794, count=1, rn=6),
#  Row(ownerId=266328305, likerId=213205470, count=1, rn=7),
#  Row(ownerId=266328305, likerId=256734045, count=1, rn=8),
#  Row(ownerId=266328305, likerId=292785209, count=1, rn=9),
#  Row(ownerId=266328305, likerId=309828035, count=1, rn=10),
#  Row(ownerId=267675607, likerId=219080408, count=1, rn=1),
#  ...]

# %% [markdown]
# # Task 6
# Probable friends. If two users like each other posts they may be friends. Find pairs of users where both users are top likers of each other.

# %%
df2 = fans_of(24147)
df2.show()
# Out:
# +---------+-------+-----+
# |      fan|ownerId|likes|
# +---------+-------+-----+
# |331853691|  24147|   49|
# | 31609798|  24147|   44|
# |529276371|  24147|   43|
# |431349700|  24147|   33|
# |    24147|  24147|   25|
# | 34587765|  24147|   24|
# |   188799|  24147|   21|
# | 13898859|  24147|   19|
# | 10260310|  24147|   15|
# | 70922560|  24147|   15|
# +---------+-------+-----+

# %%
def isFriends(userId1, userId2):
    df1 = fans_of(userId1)
    df2 = fans_of(userId2)
    df3 = df1.alias("a")\
        .join(df2.alias("b"), [(col('b.fan') == col('a.ownerId')) & (col('a.fan') == col('b.ownerId'))], 'inner')\
        .select(col('a.fan'), col('a.ownerId'))
    return df3.count() > 0

# %%
print(f'UserId 24147 and userId 27419 are friends: {isFriends(27419, 24147)}')
#false потому что 27419 не в топе у 24147, хотя у последнего первый в топе есть (см. ячейки с визуализацией df1, df2 выше)
# Out:
# UserId 24147 and userId 27419 are friends: False

# %%
'''

идея: считаем предварительно число лайков пользователей друг другу. 
Берем окно по конкретному ownerId с сортировкой по убыванию по числу лайков.
Из этого окна берем первые 10 строчек, т.е. топ-10 фанов данного ownerId.
Сортировка по likerId нужна, чтобы из пользователей с одинаковым count всегда на первых позициях были одни и те же.
Получаем датасет, состоящий из топ-10 каждого ownerId.
Выполняем inner join этого датасета с самим собой. Ключ: ownerId == likerId & likerId == ownerId, т.е. пользователи
лайкают друг друга, а так как у нас датасет это совокупность топ-10, то эти пользователи еще и в топ-10 друг у друга.
Дропаем строки, где пользователь лайкает сам себя.
Получаем искомый датасет.
Результат для конкретной пары можно проверить функцией isFriends()

'''
from pyspark.sql.window import *
from pyspark.sql.functions import row_number
w = Window.partitionBy("ownerId").orderBy(desc('count'), 'likerId')

# %%
dfTop = followers_posts_likes_df.groupBy('ownerId', 'likerId')\
    .agg(F.count('likerId').name('count'))\
    .withColumn("rn", row_number().over(w))\
    .where(col("rn") < 11)

# %%
prob_friends_df = dfTop.alias("a")\
        .join(dfTop.alias("b"), [(col('b.likerId') == col('a.ownerId')) & (col('a.likerId') == col('b.ownerId'))], 'inner')\
        .select(col('a.likerId'), col('a.ownerId'))\
        .where(col('a.likerId') != col('a.ownerId'))

# %%
prob_friends_df.collect()
# Out:
# [Row(likerId=168438070, ownerId=90898752),
#  Row(likerId=209077977, ownerId=272076217),
#  Row(likerId=49894967, ownerId=56706631),
#  Row(likerId=40147706, ownerId=173546700),
#  Row(likerId=180062188, ownerId=205353671),
#  Row(likerId=371979170, ownerId=460296349),
#  Row(likerId=222900543, ownerId=9836958),
#  Row(likerId=94967714, ownerId=162535930),
#  Row(likerId=106679661, ownerId=439992443),
#  Row(likerId=136217422, ownerId=25302595),
#  Row(likerId=508532888, ownerId=119179149),
#  Row(likerId=2610724, ownerId=3860798),
#  Row(likerId=100686926, ownerId=54101707),
#  Row(likerId=1181958, ownerId=147035701),
#  Row(likerId=560369353, ownerId=546205633),
#  Row(likerId=2392313, ownerId=65913859),
#  Row(likerId=132884992, ownerId=152266279),
#  Row(likerId=20098738, ownerId=91826324),
#  Row(likerId=28405519, ownerId=98102371),
#  Row(likerId=460296349, ownerId=371979170),
#  Row(likerId=590636, ownerId=50344793),
#  Row(likerId=71427292, ownerId=70730078),
#  Row(likerId=10025180, ownerId=366769452),
#  Row(likerId=235077877, ownerId=3413929),
#  Row(likerId=229861638, ownerId=19261491),
#  Row(likerId=320690911, ownerId=172827159),
#  Row(likerId=291744331, ownerId=449367322),
#  Row(likerId=546205633, ownerId=560369353),
#  Row(likerId=21082845, ownerId=52642102),
#  Row(likerId=106929635, ownerId=106487922),
#  Row(likerId=178411788, ownerId=106487922),
#  Row(likerId=503541072, ownerId=116795739),
#  Row(likerId=255396611, ownerId=218091600),
#  Row(likerId=536236, ownerId=439690965),
#  Row(likerId=41059486, ownerId=59875894),
#  Row(likerId=29433609, ownerId=100686926),
#  Row(likerId=54101707, ownerId=100686926),
#  Row(likerId=75594119, ownerId=135195707),
#  Row(likerId=371332399, ownerId=138072354),
#  Row(likerId=133514466, ownerId=164404406),
#  Row(likerId=6173398, ownerId=99752),
#  Row(likerId=135195707, ownerId=75594119),
#  Row(likerId=22651568, ownerId=101460038),
#  Row(likerId=106487922, ownerId=178411788),
#  Row(likerId=1419707, ownerId=2610724),
#  Row(likerId=3860798, ownerId=2610724),
#  Row(likerId=3071355, ownerId=2923196),
#  Row(likerId=129921, ownerId=16339871),
#  Row(likerId=77688550, ownerId=158502573),
#  Row(likerId=12742533, ownerId=518267541),
#  Row(likerId=176690414, ownerId=152860977),
#  Row(likerId=390861832, ownerId=152860977),
#  Row(likerId=253853669, ownerId=185699403),
#  Row(likerId=166973719, ownerId=199879499),
#  Row(likerId=267529622, ownerId=199879499),
#  Row(likerId=139663519, ownerId=213192393),
#  Row(likerId=518267541, ownerId=12742533),
#  Row(likerId=226842380, ownerId=12742533),
#  Row(likerId=40147706, ownerId=148659818),
#  Row(likerId=20305012, ownerId=19549000),
#  Row(likerId=264049366, ownerId=470163231),
#  Row(likerId=39047325, ownerId=1483070),
#  Row(likerId=327426860, ownerId=62091047),
#  Row(likerId=228677214, ownerId=164749758),
#  Row(likerId=43225330, ownerId=9845081),
#  Row(likerId=140186736, ownerId=183898492),
#  Row(likerId=10484132, ownerId=45938510),
#  Row(likerId=64235926, ownerId=45938510),
#  Row(likerId=218400468, ownerId=372497194),
#  Row(likerId=260517, ownerId=240759),
#  Row(likerId=121978838, ownerId=141516892),
#  Row(likerId=45266920, ownerId=188264983),
#  Row(likerId=19261491, ownerId=229861638),
#  Row(likerId=512140188, ownerId=510323346),
#  Row(likerId=510323541, ownerId=510323346),
#  Row(likerId=56706631, ownerId=49894967),
#  Row(likerId=30857751, ownerId=52185600),
#  Row(likerId=45938510, ownerId=10484132),
#  Row(likerId=1348305, ownerId=51735514),
#  Row(likerId=174184652, ownerId=116024647),
#  Row(likerId=482937697, ownerId=116024647),
#  Row(likerId=72013331, ownerId=116024647),
#  Row(likerId=12742533, ownerId=226842380),
#  Row(likerId=563676374, ownerId=504242796),
#  Row(likerId=199879499, ownerId=267529622),
#  Row(likerId=126077130, ownerId=157644700),
#  Row(likerId=57363, ownerId=938845),
#  Row(likerId=183535934, ownerId=13675440),
#  Row(likerId=371026267, ownerId=172932695),
#  Row(likerId=133943261, ownerId=371332399),
#  Row(likerId=138072354, ownerId=371332399),
#  Row(likerId=119179149, ownerId=508532888),
#  Row(likerId=67288357, ownerId=112174899),
#  Row(likerId=371731113, ownerId=112174899),
#  Row(likerId=272076217, ownerId=209077977),
#  Row(likerId=97837808, ownerId=234284553),
#  Row(likerId=170871802, ownerId=32224206),
#  Row(likerId=136060271, ownerId=108573613),
#  Row(likerId=108573613, ownerId=136060271),
#  Row(likerId=469748984, ownerId=534101071),
#  Row(likerId=2610724, ownerId=1419707),
#  Row(likerId=18239724, ownerId=214298116),
#  Row(likerId=45266920, ownerId=43925992),
#  Row(likerId=50966505, ownerId=36056096),
#  Row(likerId=25302595, ownerId=136217422),
#  Row(likerId=510378804, ownerId=472505514),
#  Row(likerId=215704621, ownerId=65976171),
#  Row(likerId=150552012, ownerId=323532209),
#  Row(likerId=170671147, ownerId=38160061),
#  Row(likerId=38380198, ownerId=50244876),
#  Row(likerId=38160061, ownerId=170671147),
#  Row(likerId=512229422, ownerId=513273983),
#  Row(likerId=591512, ownerId=54071),
#  Row(likerId=98302865, ownerId=4741806),
#  Row(likerId=98302865, ownerId=9429274),
#  Row(likerId=52280514, ownerId=60221743),
#  Row(likerId=159389, ownerId=264743483),
#  Row(likerId=141791937, ownerId=424355295),
#  Row(likerId=29224349, ownerId=51420863),
#  Row(likerId=452280411, ownerId=464220898),
#  Row(likerId=60221743, ownerId=52280514),
#  Row(likerId=121213779, ownerId=133718619),
#  Row(likerId=161110170, ownerId=106131559),
#  Row(likerId=305592008, ownerId=298370272),
#  Row(likerId=2923196, ownerId=3071355),
#  Row(likerId=94372315, ownerId=27832142),
#  Row(likerId=1483070, ownerId=39047325),
#  Row(likerId=106247308, ownerId=67050872),
#  Row(likerId=68357465, ownerId=131564805),
#  Row(likerId=148023312, ownerId=151117071),
#  Row(likerId=6753333, ownerId=31506799),
#  Row(likerId=464220898, ownerId=452280411),
#  Row(likerId=451211328, ownerId=452280411),
#  Row(likerId=11446406, ownerId=26940265),
#  Row(likerId=449367322, ownerId=291744331),
#  Row(likerId=45938510, ownerId=64235926),
#  Row(likerId=53072575, ownerId=135521397),
#  Row(likerId=51420863, ownerId=29224349),
#  Row(likerId=68357465, ownerId=29224349),
#  Row(likerId=157644700, ownerId=126077130),
#  Row(likerId=306641566, ownerId=126077130),
#  Row(likerId=140727039, ownerId=142991458),
#  Row(likerId=372497194, ownerId=218400468),
#  Row(likerId=449193065, ownerId=53943763),
#  Row(likerId=3413929, ownerId=235077877),
#  Row(likerId=44696067, ownerId=644750),
#  Row(likerId=80211123, ownerId=2277943),
#  Row(likerId=29224349, ownerId=68357465),
#  Row(likerId=131564805, ownerId=68357465),
#  Row(likerId=23709373, ownerId=18239724),
#  Row(likerId=214298116, ownerId=18239724),
#  Row(likerId=19549000, ownerId=20305012),
#  Row(likerId=75665284, ownerId=57771381),
#  Row(likerId=103229751, ownerId=44770563),
#  Row(likerId=9836958, ownerId=222900543),
#  Row(likerId=399826586, ownerId=350057128),
#  Row(likerId=54071, ownerId=591512),
#  Row(likerId=284954315, ownerId=217533754),
#  Row(likerId=39823750, ownerId=64860197),
#  Row(likerId=62091047, ownerId=327426860),
#  Row(likerId=7059845, ownerId=13690452),
#  Row(likerId=511479489, ownerId=511589004),
#  Row(likerId=484523, ownerId=473831),
#  Row(likerId=439992443, ownerId=106679661),
#  Row(likerId=141516892, ownerId=121978838),
#  Row(likerId=91826324, ownerId=20098738),
#  Row(likerId=71104402, ownerId=122811263),
#  Row(likerId=69590814, ownerId=52827500),
#  Row(likerId=74664407, ownerId=370279256),
#  Row(likerId=366769452, ownerId=10025180),
#  Row(likerId=145291328, ownerId=87779884),
#  Row(likerId=53943763, ownerId=449193065),
#  Row(likerId=154587418, ownerId=215704621),
#  Row(likerId=65976171, ownerId=215704621),
#  Row(likerId=50344793, ownerId=590636),
#  Row(likerId=18589, ownerId=18751),
#  Row(likerId=30833356, ownerId=19013041),
#  Row(likerId=234284553, ownerId=97837808),
#  Row(likerId=368298839, ownerId=107441011),
#  Row(likerId=5620711, ownerId=2285824),
#  Row(likerId=168620551, ownerId=74403239),
#  Row(likerId=51735514, ownerId=1348305),
#  Row(likerId=25475641, ownerId=45911382),
#  Row(likerId=199879499, ownerId=166973719),
#  Row(likerId=133128915, ownerId=163562629),
#  Row(likerId=371332399, ownerId=133943261),
#  Row(likerId=122811263, ownerId=71104402),
#  Row(likerId=182583916, ownerId=113344384),
#  Row(likerId=220055248, ownerId=249635012),
#  Row(likerId=50684146, ownerId=253431187),
#  Row(likerId=506820963, ownerId=510323435),
#  Row(likerId=65913859, ownerId=2392313),
#  Row(likerId=36056096, ownerId=50966505),
#  Row(likerId=152860977, ownerId=390861832),
#  Row(likerId=32697176, ownerId=105996169),
#  Row(likerId=30583016, ownerId=25475641),
#  Row(likerId=45911382, ownerId=25475641),
#  Row(likerId=98102371, ownerId=28405519),
#  Row(likerId=73434913, ownerId=29348285),
#  Row(likerId=381962835, ownerId=495273917),
#  Row(likerId=385357647, ownerId=81724953),
#  Row(likerId=336991647, ownerId=84184518),
#  Row(likerId=152266279, ownerId=132884992),
#  Row(likerId=13675440, ownerId=183535934),
#  Row(likerId=176762433, ownerId=198012335),
#  Row(likerId=185980565, ownerId=269860760),
#  Row(likerId=327214010, ownerId=510378804),
#  Row(likerId=472505514, ownerId=510378804),
#  Row(likerId=18078590, ownerId=47896318),
#  Row(likerId=269860760, ownerId=185980565),
#  Row(likerId=112174899, ownerId=371731113),
#  Row(likerId=90898752, ownerId=168438070),
#  Row(likerId=52642102, ownerId=21082845),
#  Row(likerId=369797395, ownerId=505221775),
#  Row(likerId=116024647, ownerId=174184652),
#  Row(likerId=534101071, ownerId=469748984),
#  Row(likerId=188548515, ownerId=101767883),
#  Row(likerId=213192393, ownerId=139663519),
#  Row(likerId=301989743, ownerId=139663519),
#  Row(likerId=34776173, ownerId=165016992),
#  Row(likerId=205682294, ownerId=277115846),
#  Row(likerId=240759, ownerId=260517),
#  Row(likerId=10518257, ownerId=30366429),
#  Row(likerId=165016992, ownerId=34776173),
#  Row(likerId=1499498, ownerId=3914792),
#  Row(likerId=133718619, ownerId=121213779),
#  Row(likerId=163562629, ownerId=133128915),
#  Row(likerId=37761958, ownerId=110635670),
#  Row(likerId=452280411, ownerId=451211328),
#  Row(likerId=135521397, ownerId=53072575),
#  Row(likerId=370279256, ownerId=74664407),
#  Row(likerId=44770563, ownerId=103229751),
#  Row(likerId=151117071, ownerId=148023312),
#  Row(likerId=264743483, ownerId=159389),
#  Row(likerId=35236012, ownerId=7812093),
#  Row(likerId=108408, ownerId=7697818),
#  Row(likerId=94905465, ownerId=26209374),
#  Row(likerId=183898492, ownerId=140186736),
#  Row(likerId=15395137, ownerId=20908355),
#  Row(likerId=115252127, ownerId=83892412),
#  Row(likerId=204600866, ownerId=96882448),
#  Row(likerId=53871390, ownerId=115174115),
#  Row(likerId=217533754, ownerId=284954315),
#  Row(likerId=147035701, ownerId=1181958),
#  Row(likerId=87779884, ownerId=145291328),
#  Row(likerId=113344384, ownerId=182583916),
#  Row(likerId=185699403, ownerId=253853669),
#  Row(likerId=258277112, ownerId=369797395),
#  Row(likerId=505221775, ownerId=369797395),
#  Row(likerId=95233401, ownerId=126450311),
#  Row(likerId=439690965, ownerId=536236),
#  Row(likerId=644750, ownerId=44696067),
#  Row(likerId=165580957, ownerId=371026267),
#  Row(likerId=172932695, ownerId=371026267),
#  Row(likerId=505623447, ownerId=446881639),
#  Row(likerId=313489913, ownerId=307593556),
#  Row(likerId=208353206, ownerId=54019677),
#  Row(likerId=54856092, ownerId=125468311),
#  Row(likerId=152860977, ownerId=176690414),
#  Row(likerId=139663519, ownerId=301989743),
#  Row(likerId=107441011, ownerId=368298839),
#  Row(likerId=455234786, ownerId=512449494),
#  Row(likerId=509121827, ownerId=512449494),
#  Row(likerId=54019677, ownerId=208353206),
#  Row(likerId=938845, ownerId=57363),
#  Row(likerId=126450311, ownerId=95233401),
#  Row(likerId=207134315, ownerId=208946862),
#  Row(likerId=72013331, ownerId=482937697),
#  Row(likerId=116024647, ownerId=482937697),
#  Row(likerId=47896318, ownerId=18078590),
#  Row(likerId=115174115, ownerId=53871390),
#  Row(likerId=377805819, ownerId=49608662),
#  Row(likerId=26209374, ownerId=94905465),
#  Row(likerId=74403239, ownerId=168620551),
#  Row(likerId=208946862, ownerId=207134315),
#  Row(likerId=52827500, ownerId=69590814),
#  Row(likerId=198012335, ownerId=176762433),
#  Row(likerId=18239724, ownerId=23709373),
#  Row(likerId=64927354, ownerId=379173),
#  Row(likerId=53720099, ownerId=7786394),
#  Row(likerId=106487922, ownerId=106929635),
#  Row(likerId=4724247, ownerId=137809153),
#  Row(likerId=183582291, ownerId=137809153),
#  Row(likerId=137809153, ownerId=183582291),
#  Row(likerId=7812093, ownerId=35236012),
#  Row(likerId=101767883, ownerId=188548515),
#  Row(likerId=298370272, ownerId=305592008),
#  Row(likerId=83892412, ownerId=115252127),
#  Row(likerId=181712338, ownerId=401126930),
#  Row(likerId=482937697, ownerId=72013331),
#  Row(likerId=116024647, ownerId=72013331),
#  Row(likerId=53720099, ownerId=52612744),
#  Row(likerId=99752, ownerId=6173398),
#  Row(likerId=59875894, ownerId=41059486),
#  Row(likerId=70730078, ownerId=71427292),
#  Row(likerId=67050872, ownerId=106247308),
#  Row(likerId=323532209, ownerId=150552012),
#  Row(likerId=495273917, ownerId=381962835),
#  Row(likerId=512140188, ownerId=500307966),
#  Row(likerId=511589004, ownerId=511479489),
#  Row(likerId=137809153, ownerId=4724247),
#  Row(likerId=31506799, ownerId=6753333),
#  Row(likerId=17055245, ownerId=18202914),
#  Row(likerId=2412819, ownerId=19604518),
#  Row(likerId=142991458, ownerId=140727039),
#  Row(likerId=500307966, ownerId=512140188),
#  Row(likerId=510323346, ownerId=512140188),
#  Row(likerId=19604518, ownerId=2412819),
#  Row(likerId=7173094, ownerId=279512),
#  Row(likerId=8436545, ownerId=4123707),
#  Row(likerId=3406455, ownerId=106132175),
#  Row(likerId=9845081, ownerId=43225330),
#  Row(likerId=460363250, ownerId=459543145),
#  Row(likerId=505623447, ownerId=495108427),
#  Row(likerId=116795739, ownerId=503541072),
#  Row(likerId=7697818, ownerId=108408),
#  Row(likerId=100686926, ownerId=29433609),
#  Row(likerId=37391284, ownerId=6208673),
#  Row(likerId=350057128, ownerId=399826586),
#  Row(likerId=307593556, ownerId=313489913),
#  Row(likerId=3616615, ownerId=6752281),
#  Row(likerId=27832142, ownerId=94372315),
#  Row(likerId=292503855, ownerId=97823041),
#  Row(likerId=198102380, ownerId=149218047),
#  Row(likerId=118957635, ownerId=176479954),
#  Row(likerId=369797395, ownerId=258277112),
#  Row(likerId=13690452, ownerId=7059845),
#  Row(likerId=162535930, ownerId=94967714),
#  Row(likerId=558747, ownerId=1815328),
#  Row(likerId=53174947, ownerId=52709986),
#  Row(likerId=19013041, ownerId=30833356),
#  Row(likerId=110635670, ownerId=37761958),
#  Row(likerId=4123707, ownerId=8436545),
#  Row(likerId=180062188, ownerId=58809554),
#  Row(likerId=513273983, ownerId=512229422),
#  Row(likerId=93749480, ownerId=304745115),
#  Row(likerId=126077130, ownerId=306641566),
#  Row(likerId=279512, ownerId=7173094),
#  Row(likerId=105996169, ownerId=32697176),
#  Row(likerId=304745115, ownerId=93749480),
#  Row(likerId=43925992, ownerId=45266920),
#  Row(likerId=188264983, ownerId=45266920),
#  Row(likerId=401126930, ownerId=181712338),
#  Row(likerId=76079626, ownerId=82835284),
#  Row(likerId=164404406, ownerId=133514466),
#  Row(likerId=2285824, ownerId=5620711),
#  Row(likerId=459543145, ownerId=460363250),
#  Row(likerId=30366429, ownerId=10518257),
#  Row(likerId=52612744, ownerId=53720099),
#  Row(likerId=7786394, ownerId=53720099),
#  Row(likerId=57771381, ownerId=75665284),
#  Row(likerId=4741806, ownerId=98302865),
#  Row(likerId=9429274, ownerId=98302865),
#  Row(likerId=510378804, ownerId=327214010),
#  Row(likerId=509121827, ownerId=496088573),
#  Row(likerId=173546700, ownerId=40147706),
#  Row(likerId=148659818, ownerId=40147706),
#  Row(likerId=52709986, ownerId=53174947),
#  Row(likerId=293462793, ownerId=153043191),
#  Row(likerId=277115846, ownerId=205682294),
#  Row(likerId=1815328, ownerId=558747),
#  Row(likerId=32224206, ownerId=170871802),
#  Row(likerId=473831, ownerId=484523),
#  Row(likerId=218091600, ownerId=255396611),
#  Row(likerId=18202914, ownerId=17055245),
#  Row(likerId=114219578, ownerId=21892949),
#  Row(likerId=106131559, ownerId=161110170),
#  Row(likerId=321585651, ownerId=56060470),
#  Row(likerId=116714509, ownerId=88359321),
#  Row(likerId=97823041, ownerId=292503855),
#  Row(likerId=153043191, ownerId=293462793),
#  Row(likerId=504242796, ownerId=563676374),
#  Row(likerId=253431187, ownerId=50684146),
#  Row(likerId=470163231, ownerId=264049366),
#  Row(likerId=49608662, ownerId=377805819),
#  Row(likerId=495108427, ownerId=505623447),
#  Row(likerId=446881639, ownerId=505623447),
#  Row(likerId=6208673, ownerId=37391284),
#  Row(likerId=6752281, ownerId=3616615),
#  Row(likerId=510323435, ownerId=506820963),
#  Row(likerId=172827159, ownerId=320690911),
#  Row(likerId=50244876, ownerId=38380198),
#  Row(likerId=2277943, ownerId=80211123),
#  Row(likerId=112174899, ownerId=67288357),
#  Row(likerId=176479954, ownerId=118957635),
#  Row(likerId=56060470, ownerId=321585651),
#  Row(likerId=40048641, ownerId=6563714),
#  Row(likerId=52185600, ownerId=30857751),
#  Row(likerId=371026267, ownerId=165580957),
#  Row(likerId=249635012, ownerId=220055248),
#  Row(likerId=3914792, ownerId=1499498),
#  Row(likerId=164749758, ownerId=228677214),
#  Row(likerId=81724953, ownerId=385357647),
#  Row(likerId=496088573, ownerId=509121827),
#  Row(likerId=512449494, ownerId=509121827),
#  Row(likerId=20908355, ownerId=15395137),
#  Row(likerId=64860197, ownerId=39823750),
#  Row(likerId=125468311, ownerId=54856092),
#  Row(likerId=82835284, ownerId=76079626),
#  Row(likerId=158502573, ownerId=77688550),
#  Row(likerId=66022003, ownerId=326871725),
#  Row(likerId=18751, ownerId=18589),
#  Row(likerId=29348285, ownerId=73434913),
#  Row(likerId=21892949, ownerId=114219578),
#  Row(likerId=88359321, ownerId=116714509),
#  Row(likerId=96882448, ownerId=204600866),
#  Row(likerId=215704621, ownerId=154587418),
#  Row(likerId=6563714, ownerId=40048641),
#  Row(likerId=205353671, ownerId=180062188),
#  Row(likerId=58809554, ownerId=180062188),
#  Row(likerId=84184518, ownerId=336991647),
#  Row(likerId=510323346, ownerId=510323541),
#  Row(likerId=106132175, ownerId=3406455),
#  Row(likerId=26940265, ownerId=11446406),
#  Row(likerId=379173, ownerId=64927354),
#  Row(likerId=326871725, ownerId=66022003),
#  Row(likerId=16339871, ownerId=129921),
#  Row(likerId=424355295, ownerId=141791937),
#  Row(likerId=101460038, ownerId=22651568),
#  Row(likerId=25475641, ownerId=30583016),
#  Row(likerId=149218047, ownerId=198102380),
#  Row(likerId=512449494, ownerId=455234786)]

# %%
isFriends(1181958, 147035701)
# Out:
# True

# %% [markdown]
# ### Draft
# Источник вдохновения. Удаляется без последствий для основной части

# %%
followers_posts_likes_df.groupBy('ownerId', 'likerId')\
    .agg(F.count('likerId').name('count'))\
    .where((col('ownerId') == 2212))\
    .orderBy('likerId')\
    .collect()

# %%
users_df = list(followers_posts_likes_df.select('likerId')\
    .distinct()\
    .toPandas()['likerId'])

# %%
prob_friends = {}
for userId in users_df:
    fans = fans_of(userId)
    if fans.count() != 0:
        prob_friends[userId] = []
        for fan in fans.select('fan').collect()[0]:
            if isFriends(fan, userId):
                prob_friends[userId].append(fan)
prob_friends

# %%
windowSpecAgg  = Window.partitionBy("likerId")

followers_posts_likes_df

# %%
prob_friends_df = followers_posts_likes_df.alias("a")\
        .join(df1.alias("b"), [(col('b.likerId') == col('a.ownerId')) & (col('a.likerId') == col('b.ownerId'))], 'inner')\
        .select(col('a.likerId'), col('a.ownerId'))\
        .groupBy('ownerId', 'likerId')\
        .agg(F.count('ownerId').name('count'))\
        .orderBy('likerId')

# %%
prob_friends_df.show()

# %%
#a = {}
#a['key'] = []
#a['rer'] = []
a['key'].append(5)
a['rer'].append(1)
a

# %%
followers_posts_likes_df.where('likerId = 2767')\
    .agg(F.count('ownerId').name('likes'))\
    .collect()
